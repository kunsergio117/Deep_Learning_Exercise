# %%
import nltk
from nltk.corpus import movie_reviews
from sklearn.metrics import confusion_matrix
import pandas as pd

# %% [markdown]
# # Sentiment Analysis on Movie Reviews

# %% [markdown]
# We will be working with sentiment analysis on movie reviews. This dataset is originally taken from http://www.cs.cornell.edu/people/pabo/movie-review-data/ but NLTK has loaded into the list of corpus (under `nltk.corpus.movie_reviews`). We will use the one from NLTK for ease of use.

# %%
#the original dataset has 2000 reviews (1000 negative reviews & 1000 positive reviews)
#each in a separate file with different filename
print(len(movie_reviews.fileids()))
print(movie_reviews.fileids()[:10])
# Out:
# 2000
# ['neg/cv000_29416.txt', 'neg/cv001_19502.txt', 'neg/cv002_17424.txt', 'neg/cv003_12683.txt', 'neg/cv004_12641.txt', 'neg/cv005_29357.txt', 'neg/cv006_17022.txt', 'neg/cv007_4992.txt', 'neg/cv008_29326.txt', 'neg/cv009_29417.txt']

# %%
#this will get all the fileids for the 1000 negative reviews
print(len(movie_reviews.fileids("neg")))
print(movie_reviews.fileids("neg")[:10])
# Out:
# 1000
# ['neg/cv000_29416.txt', 'neg/cv001_19502.txt', 'neg/cv002_17424.txt', 'neg/cv003_12683.txt', 'neg/cv004_12641.txt', 'neg/cv005_29357.txt', 'neg/cv006_17022.txt', 'neg/cv007_4992.txt', 'neg/cv008_29326.txt', 'neg/cv009_29417.txt']

# %%
#this will get all the fileids for the 1000 positive reviews
print(len(movie_reviews.fileids("pos")))
print(movie_reviews.fileids("pos")[:10])
# Out:
# 1000
# ['pos/cv000_29590.txt', 'pos/cv001_18431.txt', 'pos/cv002_15918.txt', 'pos/cv003_11664.txt', 'pos/cv004_11636.txt', 'pos/cv005_29443.txt', 'pos/cv006_15448.txt', 'pos/cv007_4968.txt', 'pos/cv008_29435.txt', 'pos/cv009_29592.txt']

# %%
#get one review (raw text)
pos_review1 = movie_reviews.raw("pos/cv000_29590.txt")
pos_review1
# Out:
# 'films adapted from comic books have had plenty of success , whether they\'re about superheroes ( batman , superman , spawn ) , or geared toward kids ( casper ) or the arthouse crowd ( ghost world ) , but there\'s never really been a comic book like from hell before . \nfor starters , it was created by alan moore ( and eddie campbell ) , who brought the medium to a whole new level in the mid \'80s with a 12-part series called the watchmen . \nto say moore and campbell thoroughly researched the subject of jack the ripper would be like saying michael jackson is starting to look a little odd . \nthe book ( or " graphic novel , " if you will ) is over 500 pages long and includes nearly 30 more that consist of nothing but footnotes . \nin other words , don\'t dismiss this film because of its source . \nif you can get past the whole comic book thing , you might find another stumbling block in from hell\'s directors , albert and allen hughes . \ngetting the hughes brothers to direct this seems almost as ludicrous as casting carrot top in , well , anything , but riddle me this : who better to direct a film that\'s set in the ghetto and features really violent street crime than the mad geniuses behind menace ii society ? \nthe ghetto in question is , of course , whitechapel in 1888 london\'s east end . \nit\'s a filthy , sooty place where the whores ( called " unfortunates " ) are starting to get a little nervous about this mysterious psychopath who has been carving through their profession with surgical precision . \nwhen the first stiff turns up , copper peter godley ( robbie coltrane , the world is not enough ) calls in inspector frederick abberline ( johnny depp , blow ) to crack the case . \nabberline , a widower , has prophetic dreams he unsuccessfully tries to quell with copious amounts of absinthe and opium . \nupon arriving in whitechapel , he befriends an unfortunate named mary kelly ( heather graham , say it isn\'t so ) and proceeds to investigate the horribly gruesome crimes that even the police surgeon can\'t stomach . \ni don\'t think anyone needs to be briefed on jack the ripper , so i won\'t go into the particulars here , other than to say moore and campbell have a unique and interesting theory about both the identity of the killer and the reasons he chooses to slay . \nin the comic , they don\'t bother cloaking the identity of the ripper , but screenwriters terry hayes ( vertical limit ) and rafael yglesias ( les mis ? rables ) do a good job of keeping him hidden from viewers until the very end . \nit\'s funny to watch the locals blindly point the finger of blame at jews and indians because , after all , an englishman could never be capable of committing such ghastly acts . \nand from hell\'s ending had me whistling the stonecutters song from the simpsons for days ( " who holds back the electric car/who made steve guttenberg a star ? " ) . \ndon\'t worry - it\'ll all make sense when you see it . \nnow onto from hell\'s appearance : it\'s certainly dark and bleak enough , and it\'s surprising to see how much more it looks like a tim burton film than planet of the apes did ( at times , it seems like sleepy hollow 2 ) . \nthe print i saw wasn\'t completely finished ( both color and music had not been finalized , so no comments about marilyn manson ) , but cinematographer peter deming ( don\'t say a word ) ably captures the dreariness of victorian-era london and helped make the flashy killing scenes remind me of the crazy flashbacks in twin peaks , even though the violence in the film pales in comparison to that in the black-and-white comic . \noscar winner martin childs\' ( shakespeare in love ) production design turns the original prague surroundings into one creepy place . \neven the acting in from hell is solid , with the dreamy depp turning in a typically strong performance and deftly handling a british accent . \nians holm ( joe gould\'s secret ) and richardson ( 102 dalmatians ) log in great supporting roles , but t ...

# %%
#NLTK has tokenize the reviews before hand. So, we will use the list of words instead
pos_review_words1 = movie_reviews.words("pos/cv000_29590.txt")
pos_review_words1[:20]
# Out:
# ['films',
#  'adapted',
#  'from',
#  'comic',
#  'books',
#  'have',
#  'had',
#  'plenty',
#  'of',
#  'success',
#  ',',
#  'whether',
#  'they',
#  "'",
#  're',
#  'about',
#  'superheroes',
#  '(',
#  'batman',
#  ',']

# %% [markdown]
# ## Split the data into Training and Testing set

# %%
#we will do 90%/10% training/test split
training_set_size = 900

# %% [markdown]
# #### ❓Exercise 1. Create the training data by combining the first 900 rows of the positive reviews and the first 900 rows of negative reviews

# %%
training_pos_fields = movie_reviews.fileids("pos")[:training_set_size]
training_neg_fields = movie_reviews.fileids("neg")[:training_set_size]

training_data = [(movie_reviews.words(fileid), "pos") for fileid in training_pos_fields] + [(movie_reviews.words(fileid), "neg") for fileid in training_neg_fields]

# %% [markdown]
# ===

# %%
#there should be 900 + 900 = 1800 rows in the training set
print(len(training_data))
training_data
# Out:
# 1800
# [(['films', 'adapted', 'from', 'comic', 'books', 'have', ...], 'pos'),
#  (['every', 'now', 'and', 'then', 'a', 'movie', 'comes', ...], 'pos'),
#  (['you', "'", 've', 'got', 'mail', 'works', 'alot', ...], 'pos'),
#  (['"', 'jaws', '"', 'is', 'a', 'rare', 'film', 'that', ...], 'pos'),
#  (['moviemaking', 'is', 'a', 'lot', 'like', 'being', ...], 'pos'),
#  (['on', 'june', '30', ',', '1960', ',', 'a', 'self', ...], 'pos'),
#  (['apparently', ',', 'director', 'tony', 'kaye', 'had', ...], 'pos'),
#  (['one', 'of', 'my', 'colleagues', 'was', 'surprised', ...], 'pos'),
#  (['after', 'bloody', 'clashes', 'and', 'independence', ...], 'pos'),
#  (['the', 'american', 'action', 'film', 'has', 'been', ...], 'pos'),
#  (['after', 'watching', '"', 'rat', 'race', '"', 'last', ...], 'pos'),
#  (['i', "'", 've', 'noticed', 'something', 'lately', ...], 'pos'),
#  (['synopsis', ':', 'bobby', 'garfield', '(', 'yelchin', ...], 'pos'),
#  (['synopsis', ':', 'in', 'this', 'movie', ',', 'steven', ...], 'pos'),
#  (['the', 'police', 'negotiator', 'is', 'the', 'person', ...], 'pos'),
#  (['plot', ':', 'a', 'young', 'man', 'who', 'loves', ...], 'pos'),
#  (['carry', 'on', 'matron', 'is', 'the', 'last', 'great', ...], 'pos'),
#  (['the', 'ultimate', 'match', 'up', 'between', 'good', ...], 'pos'),
#  (['having', 'not', 'seen', ',', '"', 'who', 'framed', ...], 'pos'),
#  (['there', "'", 's', 'something', 'about', 'ben', ...], 'pos'),
#  (['by', 'phil', 'curtolo', 'mel', 'gibson', '(', ...], 'pos'),
#  (['one', 'can', 'not', 'observe', 'a', 'star', 'trek', ...], 'pos'),
#  (['a', 'fully', 'loaded', 'entertainment', 'review', ...], 'pos'),
#  (['when', 'bulworth', 'ended', ',', 'i', 'allowed', ...], 'pos'),
#  (['call', '911', 'for', 'the', 'cliche', 'police', 'if', ...], 'pos'),
#  (['hilarious', ',', 'ultra', '-', 'low', 'budget', ...], 'pos'),
#  (['for', 'those', 'of', 'us', 'who', 'weren', "'", 't', ...], 'pos'),
#  (['the', 'most', 'common', '(', 'and', 'in', 'many', ...], 'pos'),
#  (['"', 'the', 'blair', 'witch', 'project', '"', 'was', ...], 'pos'),
#  (['seen', 'may', '31', ',', '1999', 'on', 'home', ...], 'pos'),
#  (['linda', 'fiorentino', 'disappeared', 'off', 'the', ...], 'pos'),
#  (['you', "'", 've', 'heard', 'all', 'the', 'hype', '.', ...], 'pos'),
#  (['as', 'african', 'american', 'detective', 'vergil', ...], 'pos'),
#  (['in', 'wonder', 'boys', 'michael', 'douglas', 'plays', ...], 'pos'),
#  (['plot', ':', 'derek', 'zoolander', 'is', 'a', 'male', ...], 'pos'),
#  (['unzipped', 'is', 'a', 'cinematic', 'portrait', 'of', ...], 'pos'),
#  (['dora', '(', 'fernanda', 'montenegro', ')', 'sits', ...], 'pos'),
#  (['the', 'event', 'of', 'events', 'is', 'upon', 'us', ...], 'pos'),
#  (['sometimes', 'a', 'movie', 'comes', 'along', 'that', ...], 'pos'),
#  (['that', 'thing', 'you', 'do', '!', '(', 'r', ')', ...], 'pos'),
#  (['"', 'he', "'", 's', 'back', ',', 'and', 'it', "'", ...], 'pos'),
#  (['dreamworks', 'pictures', 'presents', 'a', 'jinks', ...], 'pos'),
#  (['will', 'hunting', '(', 'matt', 'damon', ')', 'is', ...], 'pos'),
#  (['if', 'there', "'", 's', 'one', 'thing', 'in', ...], 'pos'),
#  (['what', 'do', 'you', 'get', 'when', 'you', 'slap', ...], 'pos'),
#  (['`', 'we', 'run', 'tings', '.', 'tings', 'don', "'", ...], 'pos'),
#  (['at', 'first', 'glance', ',', 'it', 'appears', 'that', ...], 'pos'),
#  (['--', 'comedy', ',', 'rated', 'pg', ',', 'runs', ...], 'pos'),
#  (['when', '_star', 'wars_', 'came', 'out', 'some', ...], 'pos'),
#  (['warning', ':', 'contains', 'what', 'the', 'matrix', ...], 'pos'),
#  (['national', 'lampoon', "'", 's', 'animal', 'house', ...], 'pos'),
#  (['every', 'year', ',', 'hollywood', 'crowns', 'a', ...], 'pos'),
#  (['synopsis', ':', 'leonard', 'shelby', '(', 'pearce', ...], 'pos'),
#  (['earth', 'is', 'a', 'harsh', ',', 'unconsoling', ...], 'pos'),
#  (['up', 'until', 'about', 'a', 'year', 'ago', ',', ...], 'pos'),
#  (['i', 'was', 'fortunate', 'enough', 'to', 'attend', ...], 'pos'),
#  (['the', 'disney', 'studios', 'has', 'its', 'formula', ...], 'pos'),
#  (['i', 'had', 'been', 'expecting', 'more', 'of', 'this', ...], 'pos'),
#  (['disney', "'", 's', '35th', 'animated', 'feature', ...], 'pos'),
#  (['the', 'computer', '-', 'animated', 'comedy', '"', ...], 'pos'),
#  (['after', 'watching', 'the', 'first', 'ten', 'minutes', ...], 'pos'),
#  (['there', "'", 's', 'an', 'old', 'saying', 'that', ...], 'pos'),
#  (['why', 'do', 'so', 'many', 'children', "'", 's', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['roman', 'emperor', 'marcus', 'aurelius', '(', ...], 'pos'),
#  (['what', 'a', 'great', 'film', '.', 'what', 'a', ...], 'pos'),
#  (['ingredients', ':', 'starving', 'artist', 'lusting', ...], 'pos'),
#  (['you', "'", 've', 'seen', 'this', 'moment', 'before', ...], 'pos'),
#  (['hollywood', 'has', 'really', 'done', 'the', 'whole', ...], 'pos'),
#  (['stendhal', "'", 's', 'syndrome', ':', 'a', ...], 'pos'),
#  (['close', 'your', 'eyes', 'for', 'a', 'moment', ',', ...], 'pos'),
#  (['zero', 'effect', 'gets', 'its', 'title', 'from', ...], 'pos'),
#  (['the', 'long', 'kiss', 'goodnight', '(', 'r', ')', ...], 'pos'),
#  (['screen', 'story', 'by', 'kevin', 'yagher', 'and', ...], 'pos'),
#  (['mpaa', ':', 'not', 'rated', '(', 'though', 'i', ...], 'pos'),
#  (['well', ',', 'i', 'know', 'that', 'stallone', 'is', ...], 'pos'),
#  (['logical', 'time', 'travel', 'movies', 'are', 'a', ...], 'pos'),
#  (['blade', 'is', 'the', 'movie', 'that', 'shows', ...], 'pos'),
#  (['the', 'truman', 'show', '(', 'paramount', 'pictures', ...], 'pos'),
#  (['no', 'film', 'in', 'recent', 'has', 'left', 'me', ...], 'pos'),
#  (['just', 'how', 'inseparable', 'is', 'the', 'team', ...], 'pos'),
#  (['since', '1990', ',', 'the', 'dramatic', 'picture', ...], 'pos'),
#  (['a', 'big', 'surprise', 'to', 'me', '.', 'the', ...], 'pos'),
#  (['after', 'having', 'heard', 'so', 'many', 'critics', ...], 'pos'),
#  (['wild', 'things', 'is', 'a', 'suspenseful', ...], 'pos'),
#  (['*', '*', '*', '*', '*', '*', 'minor', 'plot', ...], 'pos'),
#  (['are', 'you', 'tired', 'of', 'all', 'the', 'hot', ...], 'pos'),
#  (['many', 'people', 'dislike', 'french', 'films', 'for', ...], 'pos'),
#  (['the', 'keen', 'wisdom', 'of', 'an', 'elderly', ...], 'pos'),
#  (['robert', 'benton', 'has', 'assembled', 'a', ...], 'pos'),
#  (['warning', ':', 'anyone', 'offended', 'by', 'blatant', ...], 'pos'),
#  (['accepting', 'his', 'oscar', 'as', 'producer', 'of', ...], 'pos'),
#  (['a', 'bleak', 'look', 'at', 'how', 'the', 'boston', ...], 'pos'),
#  (['"', 'footloose', '"', 'has', 'only', 'one', 'goal', ...], 'pos'),
#  (['as', 'i', 'walked', 'out', 'of', 'crouching', ...], 'pos'),
#  (['"', 'crazy', '/', 'beautiful', '"', 'suffers', ...], 'pos'),
#  (['everyone', 'knows', 'someone', 'like', 'giles', 'de', ...], 'pos'),
#  (['for', 'many', 'people', ',', 'procrastination', ...], 'pos'),
#  (['meet', 'joe', 'black', '(', 'reviewed', 'on', 'nov', ...], 'pos'),
#  (['call', 'it', 'touched', 'by', 'a', 'demon', '.', ...], 'pos'),
#  (['james', 'l', '.', 'brooks', ',', 'one', 'of', 'the', ...], 'pos'),
#  (['after', 'a', 'stylistic', 'detour', 'with', 'mrs', ...], 'pos'),
#  (['"', 'the', 'fugitive', '"', 'is', 'probably', 'one', ...], 'pos'),
#  (['i', 'think', 'that', 'any', 'competent', 'member', ...], 'pos'),
#  (['based', 'on', 'the', 'boris', 'karloff', "'", 's', ...], 'pos'),
#  (['on', 're', '-', 'watching', 'italian', 'writer', '/', ...], 'pos'),
#  (['as', 'any', 'sociologist', 'will', 'attest', ',', ...], 'pos'),
#  (['is', 'evil', 'dead', 'ii', 'a', 'bad', 'movie', '?', ...], 'pos'),
#  (['it', "'", 's', 'rather', 'strange', 'too', 'have', ...], 'pos'),
#  (['not', 'since', 'oliver', 'stone', "'", 's', ...], 'pos'),
#  (['plot', ':', 'a', 'bunch', 'of', 'bad', 'guys', ...], 'pos'),
#  (['>', 'from', 'the', 'commercials', ',', 'this', ...], 'pos'),
#  (['i', "'", 'm', 'not', 'quite', 'sure', 'how', 'best', ...], 'pos'),
#  (['the', 'sheer', 'horrific', 'audacity', 'of', 'the', ...], 'pos'),
#  (['it', 'is', 'easy', 'to', 'label', 'something', ...], 'pos'),
#  (['i', 'know', 'that', '"', 'funnest', '"', 'isn', "'", ...], 'pos'),
#  (['capsule', ':', 'a', 'short', 'punchy', 'action', ...], 'pos'),
#  (['just', 'look', 'back', 'two', 'years', 'ago', 'at', ...], 'pos'),
#  (['plot', ':', 'a', 'human', 'space', 'astronaut', ...], 'pos'),
#  (['disaster', 'films', 'have', 'a', 'tendency', 'to', ...], 'pos'),
#  (['in', 'brief', ':', 'best', 'bleak', 'comedy', 'film', ...], 'pos'),
#  (['i', 'relish', 'those', 'rare', 'opportunities', ...], 'pos'),
#  (['warning', ':', 'this', 'review', 'contains', 'some', ...], 'pos'),
#  (['andrew', 'lloyd', 'webber', "'", 's', 'musicals', ...], 'pos'),
#  (['there', "'", 's', 'more', 'to', 'a', 'quilt', 'than', ...], 'pos'),
#  (['mimi', 'leder', 'is', 'probably', 'best', 'known', ...], 'pos'),
#  (['i', 'have', 'to', 'say', 'it', '.', 'tim', 'burton', ...], 'pos'),
#  (['urban', 'legend', 'surprised', 'me', '.', 'based', ...], 'pos'),
#  (['capsule', ':', 'the', 'verma', 'family', 'is', ...], 'pos'),
#  (['the', 'love', 'for', 'family', 'is', 'one', 'of', ...], 'pos'),
#  (['while', 'watching', 'wes', 'anderson', "'", 's', ...], 'pos'),
#  (['no', ',', 'i', 'did', 'not', 'read', 'the', 'novel', ...], 'pos'),
#  (['quaid', 'stars', 'as', 'a', 'man', 'who', 'has', ...], 'pos'),
#  (['it', 'has', 'been', '20', 'years', 'since', 'a', ...], 'pos'),
#  (['"', 'stuart', 'little', '"', 'is', 'one', 'of', ...], 'pos'),
#  (['as', 'with', 'his', 'other', 'stateside', 'releases', ...], 'pos'),
#  (['the', 'premise', 'of', 'wag', 'the', 'dog', 'is', ...], 'pos'),
#  (['as', 'the', 'film', 'opens', 'up', ',', 'expectant', ...], 'pos'),
#  (['the', 'second', 'jackal', '-', 'based', 'film', 'to', ...], 'pos'),
#  (['one', 'of', 'the', 'last', 'entries', 'in', 'the', ...], 'pos'),
#  (['the', 'cryptic', 'teaser', 'trailer', 'has', 'been', ...], 'pos'),
#  (['"', 'very', 'bad', 'things', ',', '"', 'is', 'the', ...], 'pos'),
#  (['it', 'is', 'hard', 'to', 'imagine', 'that', 'a', ...], 'pos'),
#  (['known', 'as', 'the', 'most', 'successful', ',', ...], 'pos'),
#  (['the', 'dramatic', 'comedy', 'cousins', 'has', 'all', ...], 'pos'),
#  (['this', 'remake', 'of', '"', 'la', 'cage', 'aux', ...], 'pos'),
#  (['seen', 'may', '19', ',', '1999', 'at', '5', 'p', '.', ...], 'pos'),
#  (['the', 'story', 'of', 'us', ',', 'a', 'rob', 'reiner', ...], 'pos'),
#  (['warren', 'beatty', 'returns', 'to', 'the', 'screens', ...], 'pos'),
#  (['the', 'long', 'and', 'illustrious', 'career', 'of', ...], 'pos'),
#  (['in', 'recent', 'years', ',', 'harrison', 'ford', ...], 'pos'),
#  (['near', 'the', 'end', 'of', '1996', ',', 'analysts', ...], 'pos'),
#  (['capsule', ':', 'a', 'rock', 'and', 'roll', 'fable', ...], 'pos'),
#  (['jack', 'nicholson', 'has', 'a', 'funny', 'way', 'of', ...], 'pos'),
#  (['"', 'i', "'", 've', 'been', 'told', 'by', 'several', ...], 'pos'),
#  (['the', 'deer', 'hunter', ',', 'directed', 'by', ...], 'pos'),
#  (['with', 'storytelling', 'this', 'compelling', ',', ...], 'pos'),
#  (['synopsis', ':', 'committed', 'to', 'an', 'asylum', ...], 'pos'),
#  (['with', 'more', 'and', 'more', 'television', 'shows', ...], 'pos'),
#  (['with', 'his', 'last', 'two', 'films', '-', 'shine', ...], 'pos'),
#  (['corey', 'yuen', "'", 's', 'latest', 'film', ',', '"', ...], 'pos'),
#  (['synopsis', ':', 'in', 'this', 'cultural', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['this', 'christmas', ',', 'little', 'ralphie', ...], 'pos'),
#  (['in', 'intolerance', ',', 'd', '.', 'w', '.', ...], 'pos'),
#  (['contact', 'is', 'the', '1997', 'movie', 'i', "'", ...], 'pos'),
#  (['roberto', 'benigni', 'is', 'a', 'clown', 'in', 'the', ...], 'pos'),
#  (['larry', 'flynt', 'is', 'a', 'self', 'proclaimed', ...], 'pos'),
#  (['virtual', 'reality', 'is', 'a', 'topic', 'that', ...], 'pos'),
#  (['i', 'don', "'", 't', 'know', 'what', 'movie', 'the', ...], 'pos'),
#  (['it', 'was', 'with', 'great', 'trepidation', 'that', ...], 'pos'),
#  (['a', 'standoff', '.', 'a', 'man', 'holds', 'a', ...], 'pos'),
#  (['with', 'stars', 'like', 'sigourney', 'weaver', '(', ...], 'pos'),
#  (['no', ',', 'it', 'is', 'not', 'a', 'bad', 'film', ',', ...], 'pos'),
#  (['capsule', ':', 'earthy', ',', 'experimental', ',', ...], 'pos'),
#  (['a', 'fully', 'loaded', 'entertainment', 'review', ...], 'pos'),
#  (['"', 'oh', 'my', 'god', ',', 'i', 'sounded', 'just', ...], 'pos'),
#  (['i', 'don', "'", 't', 'know', 'how', 'many', 'other', ...], 'pos'),
#  (['no', 'filmmaker', 'deconstructs', 'a', 'story', 'as', ...], 'pos'),
#  (['i', 'know', 'what', 'i', 'would', 'do', 'with', '$', ...], 'pos'),
#  (['i', 'saw', 'simon', 'birch', 'in', 'a', 'basically', ...], 'pos'),
#  (['the', 'saint', 'was', 'actually', 'a', 'little', ...], 'pos'),
#  (['the', 'thirteenth', 'floor', ',', 'the', 'third', ...], 'pos'),
#  (['i', 'tried', 'hard', 'not', 'like', 'this', 'movie', ...], 'pos'),
#  (['plot', ':', 'jet', 'li', 'is', 'a', 'chinese', 'cop', ...], 'pos'),
#  (['i', "'", 've', 'never', 'been', 'a', 'member', 'of', ...], 'pos'),
#  (['weir', 'is', 'well', '-', 'respected', 'in', ...], 'pos'),
#  (['synopsis', ':', 'it', "'", 's', '1977', 'in', 'a', ...], 'pos'),
#  (['part', 'one', 'of', '"', 'the', 'strangest', ...], 'pos'),
#  (['good', 'films', 'are', 'hard', 'to', 'find', 'these', ...], 'pos'),
#  (['i', 'must', 'admit', 'i', "'", 'm', 'going', 'to', ...], 'pos'),
#  (['in', 'some', 'regards', ',', 'making', 'a', 'movie', ...], 'pos'),
#  (['on', 'the', 'basis', 'of', 'this', 'film', 'alone', ...], 'pos'),
#  (['it', "'", 's', 'a', 'fact', 'that', 'a', 'good', ...], 'pos'),
#  (['there', 'exists', 'a', 'litany', 'of', 'differences', ...], 'pos'),
#  (['jay', 'and', 'silent', 'bob', 'strike', 'back', ',', ...], 'pos'),
#  (['damn', 'those', 'trailers', '.', 'had', 'it', 'not', ...], 'pos'),
#  (['bob', 'the', 'happy', 'bastard', "'", 's', 'quickie', ...], 'pos'),
#  (['this', 'sunday', 'afternoon', 'i', 'had', 'the', ...], 'pos'),
#  (['a', 'common', 'complaint', 'amongst', 'film', ...], 'pos'),
#  (['whew', '.', 'this', 'film', 'oozes', 'energy', ',', ...], 'pos'),
#  (['steven', 'spielberg', "'", 's', '"', 'amistad', ',', ...], 'pos'),
#  (['he', 'has', 'spent', 'his', 'entire', 'life', 'in', ...], 'pos'),
#  (['being', 'that', 'it', 'is', 'a', 'foreign', ...], 'pos'),
#  (['when', 'i', 'first', 'heard', 'of', 'contact', ',', ...], 'pos'),
#  (['you', "'", 've', 'got', 'to', 'love', 'disney', '.', ...], 'pos'),
#  (['with', 'three', 'pre', '-', 'to', 'mid', '-', 'teen', ...], 'pos'),
#  (['i', 'hate', 'to', 'burst', 'your', 'bubble', ',', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['i', 'must', 'say', 'from', 'the', 'outset', 'that', ...], 'pos'),
#  (['with', 'the', 'success', 'of', 'the', 'surprise', ...], 'pos'),
#  (['ingredients', ':', 'neophyte', 'lawyer', ',', ...], 'pos'),
#  (['in', 'one', 'of', 'my', 'many', 'videos', 'i', ...], 'pos'),
#  (['capsule', ':', 'suprisingly', 'more', 'of', 'a', ...], 'pos'),
#  (['"', 'when', 'will', 'the', 'devil', 'take', 'me', ...], 'pos'),
#  (['bruce', 'barth', "'", 's', 'mellow', 'piano', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['when', 'you', 'go', 'to', 'the', 'movies', 'as', ...], 'pos'),
#  (['it', 'must', 'be', 'tough', 'to', 'be', 'a', 'mob', ...], 'pos'),
#  (['the', 'caveman', "'", 's', 'valentine', 'starring', ...], 'pos'),
#  (['expand', 'the', 'final', 'fifteen', 'minutes', 'of', ...], 'pos'),
#  (['waiting', 'at', 'the', 'train', 'station', 'near', ...], 'pos'),
#  (['because', 'the', 'press', 'screening', 'of', '"', ...], 'pos'),
#  (['in', '1977', ',', 'something', 'never', 'though', ...], 'pos'),
#  (['if', 'you', 'want', 'some', 'hearty', 'laughs', ',', ...], 'pos'),
#  (['i', 'had', 'a', 'chance', 'to', 'see', 'a', 'sneak', ...], 'pos'),
#  (['the', '"', 'submarine', '"', 'genre', 'of', 'movies', ...], 'pos'),
#  (['we', 'share', 'the', 'descent', 'into', 'darkness', ...], 'pos'),
#  (['today', ',', 'war', 'became', 'a', 'reality', 'to', ...], 'pos'),
#  (['well', ',', 'i', "'", 'll', 'admit', 'when', 'i', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['"', 'last', 'night', '"', 'could', 'have', 'an', '"', ...], 'pos'),
#  (['"', 'a', 'bug', "'", 's', 'life', '"', 'may', 'not', ...], 'pos'),
#  (['when', 'i', 'saw', 'the', 'trailer', 'for', '"', ...], 'pos'),
#  (['near', 'the', 'end', 'of', 'frank', 'capra', "'", ...], 'pos'),
#  (['jerry', 'springer', 'has', 'got', 'nothing', 'on', ...], 'pos'),
#  (['the', 'happy', 'bastard', "'", 's', '30', '-', ...], 'pos'),
#  (['"', 'six', 'days', ',', 'seven', 'nights', '"', 'is', ...], 'pos'),
#  (['the', 'release', 'of', 'dolores', 'claiborne', ...], 'pos'),
#  (['seen', 'september', '13', ',', '1998', 'at', '4', ...], 'pos'),
#  (['there', 'was', 'a', 'lot', 'riding', 'on', 'this', ...], 'pos'),
#  (['ingredients', ':', 'pouring', 'rain', ',', 'small', ...], 'pos'),
#  (['although', 'many', 'people', 'have', 'compared', ...], 'pos'),
#  (['"', 'being', 'john', 'malkovich', '"', 'is', 'the', ...], 'pos'),
#  (['as', 'feel', '-', 'good', 'formulaic', 'as', 'it', ...], 'pos'),
#  (['"', 'the', 'tailor', 'of', 'panama', '"', 'is', 'a', ...], 'pos'),
#  (['perhaps', 'it', "'", 's', 'time', 'for', 'me', 'to', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['upon', 'arriving', 'at', 'the', 'theater', 'during', ...], 'pos'),
#  (['kadosh', 'means', 'sacred', 'in', 'hebrew', '.', ...], 'pos'),
#  (['the', 'film', '"', 'magnolia', '"', 'can', 'be', ...], 'pos'),
#  (['no', 'humans', 'were', 'harmed', ',', 'tested', 'or', ...], 'pos'),
#  (['"', 'good', 'will', 'hunting', '"', 'is', 'two', ...], 'pos'),
#  (['curdled', 'is', 'a', 'deliciously', 'dark', 'and', ...], 'pos'),
#  (['it', 'is', 'often', 'said', 'by', 'his', 'fans', ...], 'pos'),
#  (['most', 'people', 'fit', 'into', 'two', 'different', ...], 'pos'),
#  (['that', "'", 's', 'the', 'question', 'i', 'asked', ...], 'pos'),
#  (['jarvis', 'cocker', 'of', 'pulp', 'once', 'said', ...], 'pos'),
#  (['richard', 'linklater', "'", 's', '"', 'slacker', ',', ...], 'pos'),
#  (['"', 'a', 'breed', 'apart', '"', 'casts', 'rutger', ...], 'pos'),
#  (['titanic', 'is', 'so', 'close', 'to', 'being', 'the', ...], 'pos'),
#  (['on', 'seeing', 'the', 'outrageous', 'previews', ...], 'pos'),
#  (['american', 'pie', 'acknowledges', 'a', 'cold', ',', ...], 'pos'),
#  (['the', '1998', 'summer', 'movie', 'season', 'is', ...], 'pos'),
#  (['one', 'way', 'of', 'telling', 'if', 'a', 'film', ...], 'pos'),
#  (['it', "'", 's', 'ironic', 'that', 'the', 'best', ...], 'pos'),
#  (['while', 'it', 'was', 'part', 'of', 'former', ...], 'pos'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'pos'),
#  (['this', 'is', 'a', 'film', 'about', 'secrets', ',', ...], 'pos'),
#  (['this', 'british', 'import', 'follows', 'the', '(', ...], 'pos'),
#  (['you', 'may', 'not', 'have', 'heard', 'of', 'lucas', ...], 'pos'),
#  (['in', 'arguably', 'the', 'most', 'anticipated', ...], 'pos'),
#  (['felix', '(', 'sami', 'bouajila', ',', '"', 'the', ...], 'pos'),
#  (['i', 'know', 'that', '"', 'funnest', '"', 'isn', "'", ...], 'pos'),
#  (['after', 'the', 'press', 'screening', 'of', '"', ...], 'pos'),
#  (['"', 'living', 'out', 'loud', ',', '"', 'is', 'the', ...], 'pos'),
#  (['`', 'oh', 'behave', '!', 'felicity', 'shagwell', ...], 'pos'),
#  (['written', 'by', 'john', 'grisham', 'and', 'robert', ...], 'pos'),
#  (['october', 'sky', 'is', 'a', 'rare', 'oddity', 'in', ...], 'pos'),
#  (['this', 'three', 'hour', 'movie', 'opens', 'up', ...], 'pos'),
#  (['while', 'watching', 'boiler', 'room', ',', 'i', ...], 'pos'),
#  (['ok', ',', 'let', "'", 's', 'get', 'one', 'thing', ...], 'pos'),
#  (['trailing', 'the', 'success', 'of', 'brit', 'humour', ...], 'pos'),
#  (['"', 'you', "'", 'll', 'go', 'ape', 'over', 'tarzan', ...], 'pos'),
#  (['you', "'", 've', 'got', 'mail', 'is', 'a', 'timely', ...], 'pos'),
#  (['according', 'to', 'hollywood', 'movies', 'made', ...], 'pos'),
#  (['written', 'by', 'mark', 'rosenthal', 'and', ...], 'pos'),
#  (['notting', 'hill', "'", 's', 'trailer', 'is', 'awful', ...], 'pos'),
#  (['[', 'note', 'that', 'followups', 'are', 'directed', ...], 'pos'),
#  (['slavery', 'is', 'bad', '.', 'after', 'hundreds', ...], 'pos'),
#  (['reflecting', 'on', '"', 'bedazzled', ',', '"', 'a', ...], 'pos'),
#  (['the', 'muppet', 'movie', 'is', 'the', 'first', ',', ...], 'pos'),
#  (['all', 'great', 'things', 'come', 'to', 'an', 'end', ...], 'pos'),
#  (['since', 'their', 'film', 'debut', 'in', '1984', ...], 'pos'),
#  (['lean', ',', 'mean', ',', 'escapist', 'thrillers', ...], 'pos'),
#  (['this', 'film', 'is', 'based', 'on', 'the', 'campy', ...], 'pos'),
#  (['1992', "'", 's', 'alien3', 'marked', 'not', 'only', ...], 'pos'),
#  (['most', 'sequels', 'don', "'", 't', 'do', 'what', ...], 'pos'),
#  (['expectation', 'rating', ':', 'a', 'bit', 'worse', ...], 'pos'),
#  (['it', 'is', 'simply', 'amazing', 'how', '"', 'the', ...], 'pos'),
#  (['the', 'jekyll', 'and', 'hyde', 'story', 'told', ...], 'pos'),
#  (['aggressive', ',', 'bleak', ',', 'and', 'unrelenting', ...], 'pos'),
#  (['gothic', 'murder', '-', 'mystery', 'yarns', 'are', ...], 'pos'),
#  (['one', 'of', 'the', 'best', 'things', 'about', 'my', ...], 'pos'),
#  (['of', 'all', 'the', 'films', 'i', "'", 've', 'come', ...], 'pos'),
#  (['in', 'essence', ',', 'good', 'will', 'hunting', 'is', ...], 'pos'),
#  (['clue', 'is', 'an', 'unfairly', 'ignored', 'comedy', ...], 'pos'),
#  (['the', 'dream', 'team', 'is', 'a', 'thoroughly', ...], 'pos'),
#  (['people', 'who', 'enjoy', 'science', 'fiction', 'are', ...], 'pos'),
#  (['i', 'find', 'most', 'of', 'television', 'so', ...], 'pos'),
#  (['"', 'the', 'celebration', '"', 'is', 'one', 'of', ...], 'pos'),
#  (['synopsis', ':', 'shrek', '(', 'myers', ')', 'is', ...], 'pos'),
#  (['matthew', 'broderick', 'and', 'high', 'school', ...], 'pos'),
#  (['the', 'rocky', 'horror', 'picture', 'show', "'", ...], 'pos'),
#  (['confession', 'time', ':', 'i', 'have', 'never', ',', ...], 'pos'),
#  (['if', 'he', 'doesn', '=', '92t', 'watch', 'out', ',', ...], 'pos'),
#  (['john', 'cusack', 'is', 'the', 'kind', 'of', 'actor', ...], 'pos'),
#  (['only', 'a', 'year', 'after', 'the', 'initial', ...], 'pos'),
#  (['the', 'full', 'monty', 'is', 'a', 'whole', 'lot', ...], 'pos'),
#  (['with', 'the', 'release', 'of', 'gattaca', ',', 'i', ...], 'pos'),
#  (['it', 'must', 'be', 'some', 'sort', 'of', 'warped', ...], 'pos'),
#  (['now', ',', 'lets', 'first', 'look', 'into', 'the', ...], 'pos'),
#  (['this', 'is', 'the', 'best', 'british', 'gangster', ...], 'pos'),
#  (['produced', 'by', 'robert', 'lantos', '&', 'stephen', ...], 'pos'),
#  (['i', 'remember', 'hearing', 'about', 'this', 'film', ...], 'pos'),
#  (['most', 'movies', 'seem', 'to', 'release', 'a', ...], 'pos'),
#  (['review', ':', 'a', 'dog', 'of', 'flanders', 'is', ...], 'pos'),
#  (['do', 'film', 'critics', 'have', 'morals', '?', 'are', ...], 'pos'),
#  (['synopsis', ':', 'retiring', 'detective', 'jerry', ...], 'pos'),
#  (['one', 'never', 'quite', 'knows', 'what', 'one', 'is', ...], 'pos'),
#  (["'", 'contact', "'", 'shows', 'why', 'jodie', ...], 'pos'),
#  (['like', 'the', 'wonderful', '1990', 'drama', ',', '"', ...], 'pos'),
#  (['in', 'the', 'company', 'of', 'men', 'made', 'a', ...], 'pos'),
#  (['the', 'booming', 'introduction', 'music', 'finishes', ...], 'pos'),
#  (['jonathan', 'demme', "'", 's', '_beloved_', ',', ...], 'pos'),
#  (['scream', '2', 'isn', "'", 't', 'quite', 'as', ...], 'pos'),
#  (['when', '17', 'year', 'old', 'beau', 'hall', '(', ...], 'pos'),
#  (['leonardo', 'decaprio', '(', 'what', "'", 's', ...], 'pos'),
#  (['voices', '.', '.', '.', '.', '.', 'trey', 'parker', ...], 'pos'),
#  (['why', 'do', 'people', 'hate', 'the', 'spice', ...], 'pos'),
#  (['more', 'than', 'forty', 'years', 'ago', ',', 'the', ...], 'pos'),
#  (['the', 'andromeda', 'strain', 'is', 'the', 'greatest', ...], 'pos'),
#  (['"', 'it', "'", 's', 'not', 'good', 'to', 'know', ...], 'pos'),
#  (['do', 'you', 'want', 'to', 'know', 'the', 'truth', ...], 'pos'),
#  (['alien', '3', 'is', 'the', 'only', 'alien', 'film', ...], 'pos'),
#  (['ultra', 'low', 'budget', 'but', 'extremely', ...], 'pos'),
#  (['elmore', 'leonard', 'has', 'quickly', 'become', ...], 'pos'),
#  (['bob', 'the', 'happy', 'bastard', "'", 's', 'quickie', ...], 'pos'),
#  (['martin', 'scorsese', "'", 's', 'kundun', ',', ...], 'pos'),
#  (['synopsis', ':', 'upper', 'middle', 'class', ',', ...], 'pos'),
#  (['though', 'it', 'is', 'a', 'fine', 'piece', 'of', ...], 'pos'),
#  (['carolco', 'pictures', 'and', 'dutch', 'director', ...], 'pos'),
#  (['with', 'the', 'abundance', 'of', 'trite', ',', ...], 'pos'),
#  (['i', 'was', 'anxious', 'to', 'see', 'this', 'for', ...], 'pos'),
#  (['to', 'paraphrase', 'a', 'song', 'title', 'from', ...], 'pos'),
#  (['as', 'a', 'revolutionary', 'war', 'hero', 'in', ...], 'pos'),
#  (['"', 'if', 'there', "'", 's', 'a', 'beast', 'in', ...], 'pos'),
#  (['contrary', 'to', 'the', 'title', ',', '"', 'the', ...], 'pos'),
#  (['you', 'don', "'", 't', 'want', 'to', 'be', 'like', ...], 'pos'),
#  (['america', 'has', 'finally', 'gotten', 'what', 'it', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['elizabeth', 'is', 'a', 'potent', 'historical', ...], 'pos'),
#  (['making', 'his', 'directorial', 'debut', ',', 'actor', ...], 'pos'),
#  (['set', 'in', 'the', 'wild', 'west', ',', 'this', ...], 'pos'),
#  (['for', 'example', ',', 'in', 'happy', 'gilmore', ',', ...], 'pos'),
#  (['"', 'when', 'it', "'", 's', 'cold', ',', 'molecules', ...], 'pos'),
#  (['"', 'the', 'end', 'of', 'the', 'affair', '"', 'is', ...], 'pos'),
#  (['titanic', 'is', ',', 'without', 'a', 'doubt', ',', ...], 'pos'),
#  (['sometimes', 'you', 'just', 'have', 'to', 'tip', ...], 'pos'),
#  (['i', 'didn', "'", 't', 'realize', 'how', 'apt', 'the', ...], 'pos'),
#  (['118', 'minutes', ';', 'not', 'rated', '(', 'though', ...], 'pos'),
#  (['okay', ',', 'let', 'me', 'first', 'say', ',', 'this', ...], 'pos'),
#  (['taking', 'a', 'few', 'tips', 'from', 'the', 'pulp', ...], 'pos'),
#  (['garry', 'shandling', 'makes', 'his', 'long', ...], 'pos'),
#  (['there', "'", 's', 'a', 'moment', 'in', 'schindler', ...], 'pos'),
#  (['i', 'recall', 'the', 'trials', 'and', 'tribulations', ...], 'pos'),
#  (['full', 'metal', 'jacket', ',', 'very', 'much', ...], 'pos'),
#  (['oliver', 'stone', "'", 's', 'latest', 'feature', ...], 'pos'),
#  (['in', 'tim', 'burton', "'", 's', '`', 'sleepy', ...], 'pos'),
#  (['ok', ',', 'i', 'admit', 'i', 'had', 'a', 'bad', ...], 'pos'),
#  (['bowfinger', 'is', 'a', 'good', 'movie', 'about', ...], 'pos'),
#  (['pulp', 'fiction', ',', 'quentin', 'tarantino', "'", ...], 'pos'),
#  (['i', 'think', 'the', 'first', 'thing', 'this', ...], 'pos'),
#  (['i', 'know', 'it', 'already', 'opened', 'in', ...], 'pos'),
#  (['capsule', ':', 'this', 'is', 'a', 'film', 'that', ...], 'pos'),
#  (['"', 'gattaca', '"', 'represents', 'a', 'solid', ...], 'pos'),
#  (['there', 'was', 'a', 'huge', 'crowd', '-', 'so', ...], 'pos'),
#  (['available', 'in', 'an', 'all', 'new', 'video', ...], 'pos'),
#  (['when', 'i', 'left', 'the', 'theater', 'after', ...], 'pos'),
#  (['melvin', 'udall', 'is', 'a', 'heartless', 'man', '.', ...], 'pos'),
#  (['i', "'", 'm', 'not', 'really', 'sure', 'what', 'to', ...], 'pos'),
#  (['the', 'first', 'thing', 'you', 'notice', 'about', ...], 'pos'),
#  (['plot', ':', 'odin', 'is', 'a', 'great', 'high', ...], 'pos'),
#  (['defending', 'your', 'life', 'is', 'an', ...], 'pos'),
#  (['jake', 'kasdan', ',', 'son', 'of', 'one', 'of', ...], 'pos'),
#  (['well', 'i', "'", 'll', 'be', 'damned', ',', 'what', ...], 'pos'),
#  (['in', '1998', ',', 'director', 'brett', 'ratner', ...], 'pos'),
#  (['shakespeare', '.', 'you', 'hardly', 'understood', ...], 'pos'),
#  (['the', 'year', 'is', '1962', 'and', 'the', 'military', ...], 'pos'),
#  (['the', 'happy', 'bastard', "'", 's', '30', '-', ...], 'pos'),
#  (['_in', 'brief', ':', '_', 'this', 'film', 'needs', ...], 'pos'),
#  (['in', 'some', 'respects', ',', 'rush', 'hour', 'is', ...], 'pos'),
#  (['my', 'fellow', 'americans', 'is', 'a', 'movie', ...], 'pos'),
#  (['in', ',', '"', 'the', 'muse', '"', 'albert', ...], 'pos'),
#  (['plot', ':', 'good', 'ol', "'", 'texan', 'kid', ...], 'pos'),
#  (['the', 'film', 'starts', 'out', 'with', 'a', 'creepy', ...], 'pos'),
#  (['i', 'have', 'to', 'admit', 'that', 'i', 'disliked', ...], 'pos'),
#  (['it', 'was', 'a', 'rainy', 'friday', 'afternoon', ...], 'pos'),
#  (['the', 'uncompromising', 'nudity', 'bared', ...], 'pos'),
#  (['george', 'little', '(', 'jonathan', 'lipnicki', ')', ...], 'pos'),
#  (['countries', 'and', 'legal', 'systems', 'that', ...], 'pos'),
#  (['frequency', 'n', '.', ',', 'the', 'number', 'of', ...], 'pos'),
#  (['"', 'psycho', 'meets', 'the', 'exorcist', 'with', ...], 'pos'),
#  (['jackie', 'brown', 'entered', 'theaters', 'with', ...], 'pos'),
#  (['directed', 'by', ':', 'pixote', 'hunt', ',', ...], 'pos'),
#  (['ingredients', ':', 'little', 'orphan', 'boy', ',', ...], 'pos'),
#  (['disney', 'cements', 'their', 'place', 'in', 'the', ...], 'pos'),
#  (['capsule', ':', 'the', 'world', 'will', 'come', 'to', ...], 'pos'),
#  (['the', 'rich', 'man', "'", 's', 'wife', 'is', 'one', ...], 'pos'),
#  (['with', 'a', 'team', 'of', '200', 'graphic', ...], 'pos'),
#  (['ladies', 'and', 'gentlemen', ',', '1997', "'", 's', ...], 'pos'),
#  (['billed', 'as', 'a', '"', 'feminist', 'sex', ...], 'pos'),
#  (['seen', 'at', 'the', '21st', 'portland', ...], 'pos'),
#  (['i', 'can', 'sum', 'up', 'first', 'strike', 'in', ...], 'pos'),
#  (['as', 'a', 'devout', 'atheist', 'and', 'an', 'avowed', ...], 'pos'),
#  (['by', 'now', 'i', 'figured', 'i', "'", 'd', 'seen', ...], 'pos'),
#  (['it', "'", 's', 'wednesday', ',', 'march', '27', ',', ...], 'pos'),
#  (['on', 'april', '12th', ',', '1912', ',', 'the', ...], 'pos'),
#  (['that', 'thing', 'you', 'do', '!', ',', 'from', ...], 'pos'),
#  (['synopsis', ':', 'an', 'attractive', 'mute', 'makeup', ...], 'pos'),
#  (['the', 'grandfather', 'of', 'italian', 'horror', ...], 'pos'),
#  (['based', 'on', 'the', 'relatively', 'unknown', '(', ...], 'pos'),
#  (['quentin', 'tarantino', 'seems', 'to', 'have', 'a', ...], 'pos'),
#  (['the', 'makers', 'of', 'jurassic', 'park', '&', 'the', ...], 'pos'),
#  (['there', 'are', 'times', 'when', 'the', 'success', ...], 'pos'),
#  (['contact', 'is', 'a', 'nobly', 'intentioned', 'but', ...], 'pos'),
#  (['david', 'cronenberg', 'presents', 'us', 'with', ...], 'pos'),
#  (['"', 'seven', '"', 'is', 'one', 'of', 'the', 'best', ...], 'pos'),
#  (['after', 'hearing', 'reviews', 'for', 'woody', ...], 'pos'),
#  (['an', 'astonishingly', 'difficult', 'movie', 'to', ...], 'pos'),
#  (['call', 'me', 'crazy', ',', 'but', 'i', 'don', "'", ...], 'pos'),
#  (['seen', 'august', '8', ',', '1998', 'at', '6', 'p', ...], 'pos'),
#  (["'", 'lake', 'placid', "'", 'is', 'definately', 'not', ...], 'pos'),
#  (['a', 'lot', 'of', 'times', 'a', 'three', '-', 'star', ...], 'pos'),
#  (['what', 'if', 'one', 'of', 'our', 'cities', 'became', ...], 'pos'),
#  (['"', 'desperate', 'measures', '"', 'was', 'something', ...], 'pos'),
#  (['what', 'is', 'a', 'scary', 'movie', 'anyhow', '?', ...], 'pos'),
#  (['a', 'wonderful', 'little', 'movie', 'that', 'is', ...], 'pos'),
#  (['this', 'is', 'a', 'good', 'year', 'if', 'you', ...], 'pos'),
#  (['scarface', ',', 'a', 'remake', 'of', 'the', '1932', ...], 'pos'),
#  (['trekkies', ',', 'roger', 'nygard', "'", 's', ...], 'pos'),
#  (['if', 'you', "'", 're', 'the', 'type', 'of', 'person', ...], 'pos'),
#  (['i', 'was', 'pleasantly', 'surprised', 'by', 'this', ...], 'pos'),
#  (['it', 'was', 'easy', 'to', 'fear', 'the', 'worst', ...], 'pos'),
#  (['pollock', 'starring', 'ed', 'harris', ',', 'marcia', ...], 'pos'),
#  (['it', "'", 's', 'been', 'a', 'long', 'time', 'since', ...], 'pos'),
#  (['warning', ':', 'if', 'you', 'actually', 'wish', 'to', ...], 'pos'),
#  (['it', 'shows', 'that', 'america', 'remains', ...], 'pos'),
#  (['the', 'ring', 'is', 'probably', 'one', 'of', 'the', ...], 'pos'),
#  (['deep', 'rising', 'is', 'one', 'of', '"', 'those', ...], 'pos'),
#  (['vampire', 'films', ',', 'as', 'well', 'as', 'other', ...], 'pos'),
#  (['this', 'has', 'some', 'major', 'spoilers', 'for', ...], 'pos'),
#  (['one', 'fun', 'activity', 'for', 'parents', 'during', ...], 'pos'),
#  (['swashbuckling', 'adventure', 'that', 'can', 'be', ...], 'pos'),
#  (['"', 'rebel', 'without', 'a', 'cause', '"', 'is', ...], 'pos'),
#  (['david', 'mamet', 'has', 'long', 'been', 'my', ...], 'pos'),
#  (['catherine', 'deane', '(', 'jennifer', 'lopez', ')', ...], 'pos'),
#  (['when', 'casting', 'the', 'key', 'part', 'of', 'the', ...], 'pos'),
#  (['"', '.', '.', 'it', "'", 's', 'certainly', 'more', ...], 'pos'),
#  (['"', 'love', 'is', 'the', 'devil', '"', 'is', 'a', ...], 'pos'),
#  (['a', 'costume', 'drama', 'set', 'in', 'the', '1500s', ...], 'pos'),
#  (['jay', 'and', 'silent', 'bob', 'strike', 'back', ...], 'pos'),
#  (['a', 'sci', 'fi', '/', 'comedy', 'starring', 'jack', ...], 'pos'),
#  (['let', "'", 's', 'face', 'it', ':', 'the', '$', '100', ...], 'pos'),
#  (['rated', ':', 'r', 'for', 'strong', 'language', ',', ...], 'pos'),
#  (['one', 'of', 'the', 'most', 'popular', 'subplots', ...], 'pos'),
#  (['if', 'this', 'keeps', 'up', ',', 'jane', 'austen', ...], 'pos'),
#  (['saving', 'private', 'ryan', '(', 'dreamworks', ')', ...], 'pos'),
#  (['50', "'", 's', '`', 'aliens', 'vs', '.', 'earth', ...], 'pos'),
#  (['the', 'trailers', 'and', 'the', 'beginning', 'of', ...], 'pos'),
#  (['apocalypse', 'now', ',', 'based', 'on', 'the', ...], 'pos'),
#  (['sometimes', 'i', 'find', '19th', 'century', ...], 'pos'),
#  (['earlier', 'this', 'year', ',', 'the', 'movie', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['just', 'in', 'time', 'for', 'halloween', 'and', ...], 'pos'),
#  (['every', 'once', 'in', 'a', 'while', 'a', 'movie', ...], 'pos'),
#  (['in', '1995', ',', 'brian', 'singer', 'and', ...], 'pos'),
#  (['it', 'has', 'happened', 'again', '.', 'a', 'movie', ...], 'pos'),
#  (['in', 'the', 'grand', 'scheme', 'of', 'mel', 'gibson', ...], 'pos'),
#  (['the', 'thought', '-', 'provoking', 'question', 'of', ...], 'pos'),
#  (['barely', 'scrapping', 'by', 'playing', 'at', 'a', ...], 'pos'),
#  (['it', "'", 's', 'an', 'interesting', 'premise', '.', ...], 'pos'),
#  (['one', 'of', 'kyle', 'mclachlan', "'", 's', 'earlier', ...], 'pos'),
#  (['i', 'want', 'to', 'correct', 'what', 'i', 'wrote', ...], 'pos'),
#  (['of', 'the', 'major', 'horror', 'sub', '-', 'genres', ...], 'pos'),
#  (['when', 'quentin', 'tarantino', 'made', '"', 'pulp', ...], 'pos'),
#  (['there', "'", 's', 'some', 'movies', 'i', 'enjoy', ...], 'pos'),
#  (['this', 'summer', ',', 'one', 'of', 'the', 'most', ...], 'pos'),
#  (['towards', 'the', 'middle', 'of', '"', 'the', 'sweet', ...], 'pos'),
#  (['losing', 'a', 'job', 'is', 'not', 'an', 'all', 'too', ...], 'pos'),
#  (['as', 'much', 'as', 'i', 'wanted', 'to', 'like', ...], 'pos'),
#  (['the', 'postman', 'delivers', 'but', 'not', 'first', ...], 'pos'),
#  (['there', 'are', 'certain', 'people', 'in', 'the', ...], 'pos'),
#  (['i', 'guess', 'it', "'", 's', 'a', 'credit', 'to', ...], 'pos'),
#  (['some', 'critics', ',', 'including', 'siskel', '&', ...], 'pos'),
#  (['much', 'ballyhoo', 'has', 'been', 'made', 'over', ...], 'pos'),
#  (['capsule', ':', 'side', '-', 'splitting', 'comedy', ...], 'pos'),
#  (['maybe', 'the', 'most', 'important', 'thing', 'about', ...], 'pos'),
#  (['as', 'i', 'write', 'the', 'review', 'for', 'the', ...], 'pos'),
#  (['are', 'we', 'victims', 'of', 'fate', 'in', 'life', ...], 'pos'),
#  (['i', "'", 'm', 'an', 'avid', 'fan', 'of', 'the', '"', ...], 'pos'),
#  (['it', 'may', 'seem', 'weird', 'to', 'begin', 'a', ...], 'pos'),
#  (['when', 'i', 'first', 'heard', 'that', 'romeo', '&', ...], 'pos'),
#  (['krippendorf', "'", 's', 'tribe', 'is', 'a', ...], 'pos'),
#  (['not', 'since', '1996', "'", 's', 'shine', ',', ...], 'pos'),
#  (['luckily', ',', 'some', 'people', 'got', 'starship', ...], 'pos'),
#  (['the', 'happy', 'bastard', "'", 's', '30', '-', ...], 'pos'),
#  (['first', ',', 'i', 'am', 'not', 'a', 'big', 'fan', ...], 'pos'),
#  (['many', 'people', 'will', 'not', 'find', 'much', 'to', ...], 'pos'),
#  (['when', 'i', 'was', 'growing', 'up', 'in', '1970s', ...], 'pos'),
#  (['one', 'of', 'the', 'sweetest', 'tales', 'to', 'ever', ...], 'pos'),
#  (['of', 'circumcision', ',', 'psychic', 'wounds', 'and', ...], 'pos'),
#  (['nosferatu', 'the', 'vampyre', '(', 'germany', '1979', ...], 'pos'),
#  (['even', 'if', 'i', 'did', 'not', 'know', 'that', ...], 'pos'),
#  (['"', 'take', 'a', 'number', ',', 'fill', 'out', 'a', ...], 'pos'),
#  (['ingredients', ':', 'london', 'gal', ',', 'fate', ',', ...], 'pos'),
#  (['sick', ':', 'the', 'life', 'and', 'death', 'of', ...], 'pos'),
#  (['studio', 'expectations', 'must', 'not', 'have', ...], 'pos'),
#  (['seen', 'december', '28', ',', '1997', 'at', '8', ':', ...], 'pos'),
#  (['james', 'jones', ',', 'one', 'of', 'the', 'major', ...], 'pos'),
#  (['an', 'energetic', ',', 'visually', 'stunning', ',', ...], 'pos'),
#  (['i', "'", 'm', 'not', 'quite', 'sure', 'what', 'to', ...], 'pos'),
#  (['capsule', ':', 'trippy', ',', 'hyperspeed', 'action', ...], 'pos'),
#  (['the', 'heartbreak', 'kid', '(', 'reviewed', 'on', ...], 'pos'),
#  (['it', "'", 's', 'a', 'curious', 'thing', '-', 'i', ...], 'pos'),
#  (['i', "'", 'll', 'be', 'the', 'first', 'to', 'admit', ...], 'pos'),
#  (['before', 'even', 'seeing', 'a', 'single', 'frame', ...], 'pos'),
#  (['the', 'heist', 'of', 'a', 'flawless', ',', '84', ...], 'pos'),
#  (['tbwp', 'is', 'probably', 'the', 'single', 'most', ...], 'pos'),
#  (['i', 'am', 'starting', 'to', 'write', 'this', ...], 'pos'),
#  (['capsule', ':', 'this', 'is', 'a', '1950s', 'or', ...], 'pos'),
#  (['don', "'", 't', 'let', 'the', 'following', 'quirks', ...], 'pos'),
#  (['getting', 'it', 'right', 'is', 'a', 'far', 'far', ...], 'pos'),
#  (['no', 'matter', 'what', 'you', 'suspect', ',', 'this', ...], 'pos'),
#  (['"', 'dangerous', 'beauty', '"', 'is', 'a', 'really', ...], 'pos'),
#  (['imagine', 'this', 'scenario', ':', 'you', 'and', ...], 'pos'),
#  (['steve', 'soderbergh', "'", 's', '"', 'sex', ',', ...], 'pos'),
#  (['synopsis', ':', 'private', 'detective', 'tom', ...], 'pos'),
#  (['to', 'me', ',', 'nicolas', 'cage', 'sounds', 'like', ...], 'pos'),
#  (['at', 'first', 'glance', ',', 'daylight', 'would', ...], 'pos'),
#  (['after', 'the', 'simple', 'looking', 'little', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['bruce', 'willis', 'and', 'sixth', 'sense', ...], 'pos'),
#  (['there', "'", 's', 'good', 'news', 'and', 'bad', ...], 'pos'),
#  (['harmless', ',', 'silly', 'and', 'fun', 'comedy', ...], 'pos'),
#  (['steven', 'spielberg', 'is', 'now', 'considered', ...], 'pos'),
#  (['with', 'the', 'exception', 'of', 'their', ...], 'pos'),
#  (['"', 'the', 'endurance', ':', 'shackleton', "'", 's', ...], 'pos'),
#  (['every', 'year', '--', 'every', 'year', 'at', 'the', ...], 'pos'),
#  (['oh', 'god', 'how', 'many', 'john', 'grisham', ...], 'pos'),
#  (['the', 'seasoned', 'capt', '.', 'dudley', 'smith', ...], 'pos'),
#  (['aliens', '!', '!', 'well', ',', 'that', 'is', 'what', ...], 'pos'),
#  (['in', 'the', 'opening', 'shot', 'of', 'midnight', ...], 'pos'),
#  (['metro', 'i', "'", 've', 'seen', 'san', 'francisco', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['plot', ':', 'a', 'peculiar', 'french', 'girl', ...], 'pos'),
#  (['eric', 'rohmer', "'", 's', '"', 'pauline', 'at', ...], 'pos'),
#  (['after', 'a', 'rather', 'disappointing', '"', 'mary', ...], 'pos'),
#  (['plot', ':', 'a', 'group', 'of', 'asbestos', ...], 'pos'),
#  (['hedwig', 'and', 'the', 'angry', 'inch', '(', '2001', ...], 'pos'),
#  (['with', 'many', 'big', '-', 'budget', 'science', ...], 'pos'),
#  (['"', 'the', 'deep', 'end', '"', 'uses', 'a', 'color', ...], 'pos'),
#  (['warning', '!', ':', 'may', 'contain', 'some', 'mild', ...], 'pos'),
#  (['underrated', 'movies', 'are', 'a', 'common', ...], 'pos'),
#  (['as', 'fairy', 'tales', 'go', ',', 'cinderella', ...], 'pos'),
#  (['it', 'stands', 'as', 'a', 'moment', 'one', 'will', ...], 'pos'),
#  (['for', 'a', 'movie', 'about', 'disco', '-', 'era', ...], 'pos'),
#  (['in', '1994', ',', 'an', 'insider', "'", 's', 'look', ...], 'pos'),
#  (['this', 'movie', 'was', 'one', 'of', 'the', 'first', ...], 'pos'),
#  (['eyes', 'wide', 'shut', 'isn', "'", 't', 'the', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['until', 'i', 'saw', 'the', 'night', 'of', 'the', ...], 'pos'),
#  (['jamaica', 'is', 'a', 'hot', 'vacation', 'spot', '.', ...], 'pos'),
#  (['denzel', 'washington', 'is', 'among', 'the', 'many', ...], 'pos'),
#  (['[', 'note', ':', 'after', 'claiming', 'otherwise', ...], 'pos'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'pos'),
#  (['one', 'of', 'the', 'funniest', 'carry', 'on', ...], 'pos'),
#  (['whenever', 'writer', '/', 'director', 'robert', ...], 'pos'),
#  (['"', 'remember', 'what', 'the', 'mpaa', 'says', ':', ...], 'pos'),
#  (['for', 'this', 'review', 'and', 'more', ',', 'visit', ...], 'pos'),
#  (['errol', 'morris', ',', 'critically', 'acclaimed', ...], 'pos'),
#  (['summary', 'five', 'liberal', 'iowa', 'graduate', ...], 'pos'),
#  (['i', 'can', 'already', 'feel', 'the', 'hate', ...], 'pos'),
#  (['hollywood', 'is', 'a', 'pimp', '.', 'a', 'fat', ',', ...], 'pos'),
#  (['back', 'in', '1998', 'dreamworks', 'unveiled', ...], 'pos'),
#  (['"', 'say', ',', 'any', 'of', 'you', 'know', 'how', ...], 'pos'),
#  (['in', '"', 'magic', 'town', '"', ',', 'jimmy', ...], 'pos'),
#  (['kevin', 'smith', 'is', 'like', 'a', 'big', 'kid', ...], 'pos'),
#  (['review', ':', 'ghost', 'dog', ':', 'the', 'way', ...], 'pos'),
#  (['i', 'rented', '"', 'brokedown', 'palace', '"', ...], 'pos'),
#  (['everyone', "'", 's', 'heard', 'about', 'this', ...], 'pos'),
#  (['in', 'october', 'of', '1997', ',', 'audiences', ...], 'pos'),
#  (['brian', 'depalma', 'needs', 'a', 'hit', '*', ...], 'pos'),
#  (['i', "'", 've', 'never', 'been', 'a', 'huge', 'fan', ...], 'pos'),
#  (['synopsis', ':', 'captain', 'picard', 'and', 'the', ...], 'pos'),
#  (['us', 'critic', '-', 'type', 'people', 'are', ...], 'pos'),
#  (['magnolia', 'left', 'me', 'relling', 'from', 'the', ...], 'pos'),
#  (['a', 'group', 'of', 'high', 'school', 'kids', 'mix', ...], 'pos'),
#  (['one', 'year', 'has', 'passed', 'since', 'the', ...], 'pos'),
#  (['john', 'carpenter', 'directed', 'this', 'stylish', ...], 'pos'),
#  (['in', 'the', 'wake', 'of', 'the', 'smashing', ...], 'pos'),
#  (['at', 'first', 'glance', ',', 'three', 'kings', ...], 'pos'),
#  (['mickey', 'mouse', 'had', 'better', 'watch', 'his', ...], 'pos'),
#  (['a', 'miracle', 'of', 'filmmaking', ',', '"', 'some', ...], 'pos'),
#  (['a', 'welcome', 'cinematic', 'trend', 'over', 'the', ...], 'pos'),
#  (['there', 'is', 'a', 'scene', 'early', 'in', 'soul', ...], 'pos'),
#  (['director', 'david', 'fincher', 'has', 'such', 'an', ...], 'pos'),
#  (['originally', 'launched', 'in', '1978', ',', 'this', ...], 'pos'),
#  (['set', 'in', 'the', 'late', '80', "'", 's', 'at', ...], 'pos'),
#  (['ever', 'wonder', 'what', 'happened', 'to', 'gabe', ...], 'pos'),
#  (['did', 'you', 'ever', 'wonder', 'if', 'dennis', ...], 'pos'),
#  (['i', 'feel', 'no', 'hesitation', 'in', 'saying', ...], 'pos'),
#  (['"', 'i', "'", 'd', 'rather', 'die', 'today', 'and', ...], 'pos'),
#  (['one', 'of', 'the', 'best', 'movies', 'i', "'", 've', ...], 'pos'),
#  (['this', 'reviewer', 'is', 'ignorant', 'of', 'what', ...], 'pos'),
#  (['i', 'have', 'a', 'soft', 'spot', 'in', 'my', 'heart', ...], 'pos'),
#  (['tarzan', 'chad', "'", 'z', '=', 'good', ')', '1999', ...], 'pos'),
#  (['i', "'", 've', 'always', 'been', 'told', 'that', ...], 'pos'),
#  (['it', 'was', 'a', 'crazy', 'time', 'in', 'france', ...], 'pos'),
#  (['what', 'surprises', 'me', 'most', 'about', 'the', ...], 'pos'),
#  (['casting', '"', 'doogie', 'howser', '"', 'star', ...], 'pos'),
#  (['historical', 'epic', 'as', 'a', 'genre', 'was', ...], 'pos'),
#  (['if', 'you', 'had', 'a', 'chance', 'to', 'create', ...], 'pos'),
#  (['in', 'one', 'scene', 'from', '"', 'the', 'people', ...], 'pos'),
#  (['we', 'all', 'know', 'the', 'fate', 'of', '"', ...], 'pos'),
#  (['director', ':', 'penelope', 'spheeris', '(', ...], 'pos'),
#  (['natural', 'born', 'killers', 'is', 'really', 'a', ...], 'pos'),
#  (['the', 'bond', 'series', 'is', 'an', 'island', 'in', ...], 'pos'),
#  (['this', 'sometimes', '-', 'tedious', 'and', 'often', ...], 'pos'),
#  (['john', 'sayles', "'", '"', 'men', 'with', 'guns', ...], 'pos'),
#  (['plot', ':', 'during', 'a', '10', '-', 'week', 'span', ...], 'pos'),
#  (['in', '`', 'enemy', 'at', 'the', 'gates', "'", ',', ...], 'pos'),
#  (['it', "'", 's', 'been', 'a', 'good', 'long', 'while', ...], 'pos'),
#  (['some', 'of', 'my', 'friends', 'who', 'went', 'to', ...], 'pos'),
#  (['vampire', 'lore', 'and', 'legend', 'has', 'always', ...], 'pos'),
#  (['if', 'the', 'current', 'trends', 'of', 'hollywood', ...], 'pos'),
#  (['jean', '-', 'luc', 'picard', '(', 'patrick', ...], 'pos'),
#  (['the', 'promotion', 'for', 'fear', 'and', 'loathing', ...], 'pos'),
#  (['james', 'cmaeron', "'", 's', 'breakthrough', ...], 'pos'),
#  (['it', 'might', 'surprise', 'some', 'to', 'know', ...], 'pos'),
#  (['kirk', 'douglas', 'is', 'one', 'of', 'those', 'rare', ...], 'pos'),
#  (['"', 'a', 'man', 'is', 'not', 'a', 'man', 'without', ...], 'pos'),
#  (['the', 'summer', 'movie', 'season', 'is', 'always', ...], 'pos'),
#  (['jacques', 'tati', "'", 's', '1953', 'classic', '"', ...], 'pos'),
#  (['i', 'had', 'lost', 'all', 'faith', 'in', 'pg', '-', ...], 'pos'),
#  (['the', '1990s', 'produced', 'two', 'brilliant', ...], 'pos'),
#  (['finding', 'the', 'courage', 'to', 'face', 'life', ...], 'pos'),
#  (['bruce', 'willis', 'stars', 'as', 'malcolm', ',', ...], 'pos'),
#  (['i', 'suppose', 'an', 'argument', 'could', 'be', ...], 'pos'),
#  (['tone', 'alone', 'cannot', 'sustain', 'a', 'film', ...], 'pos'),
#  (['hollywood', 'has', 'a', '.', '750', 'batting', ...], 'pos'),
#  (['synopsis', ':', 'rumored', 'to', 'be', 'about', 'a', ...], 'pos'),
#  (['if', 'you', "'", 've', 'ever', 'perused', 'my', ...], 'pos'),
#  (['capsule', ':', 'the', 'director', 'of', 'cure', ...], 'pos'),
#  (['when', 'i', 'first', 'heard', 'that', 'disney', "'", ...], 'pos'),
#  (['the', 'opening', 'crawl', 'tells', 'us', 'that', ...], 'pos'),
#  (['in', 'december', 'of', '1996', ',', 'a', 'little', ...], 'pos'),
#  (['the', 'last', 'steve', 'martin', 'film', 'i', 'saw', ...], 'pos'),
#  (['whenever', 'studio', 'executives', 'try', 'to', ...], 'pos'),
#  (['along', 'his', 'carreer', ',', 'mel', 'gibson', ...], 'pos'),
#  (['renown', 'surrealist', 'director', ',', 'the', '77', ...], 'pos'),
#  (['in', '1987', 'the', 'stock', 'market', 'crashed', ...], 'pos'),
#  (['look', 'back', 'at', 'all', 'the', 'times', 'in', ...], 'pos'),
#  (['three', 'things', 'i', 'learned', 'from', '"', ...], 'pos'),
#  (['in', 'my', 'reviews', 'i', 'try', 'to', 'make', ...], 'pos'),
#  (["'", 'pleasantville', "'", '(', '1998', ')', 'taps', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['plot', ':', 'a', 'big', '-', 'time', 'momma', "'", ...], 'pos'),
#  (['it', 'is', 'an', 'understood', 'passion', 'and', ...], 'pos'),
#  (['capsule', ':', 'bleak', 'and', 'point', '-', 'blank', ...], 'pos'),
#  (['you', 'don', "'", 't', 'have', 'to', 'know', 'poker', ...], 'pos'),
#  (['melvin', 'van', 'peebles', "'", '"', 'sweet', ...], 'pos'),
#  (['there', 'seem', 'to', 'be', 'two', 'reactions', 'to', ...], 'pos'),
#  (['for', 'the', 'first', 'reel', 'of', 'girls', 'town', ...], 'pos'),
#  (['"', 'the', 'fighting', 'sullivans', '"', 'contains', ...], 'pos'),
#  (['big', 'courtroom', 'thrillers', 'have', 'always', ...], 'pos'),
#  (['time', 'bandits', ',', 'from', 'director', 'terry', ...], 'pos'),
#  (['it', 'seemed', 'wholly', 'appropriate', 'that', 'at', ...], 'pos'),
#  (['charlie', 'sheen', 'stars', 'as', 'zane', ',', 'a', ...], 'pos'),
#  (['field', 'of', 'dreams', 'almost', 'defies', ...], 'pos'),
#  (['making', 'a', 'sequel', 'to', 'a', 'widely', ...], 'pos'),
#  (['let', 'me', 'first', 'say', 'that', 'the', ...], 'pos'),
#  (['alchemy', 'is', 'steeped', 'in', 'shades', 'of', ...], 'pos'),
#  (['who', 'would', 'have', 'thought', '?', 'jim', ...], 'pos'),
#  (['capsule', ':', 'this', 'is', 'a', 'harrowing', ...], 'pos'),
#  (['another', "'", 'independent', 'film', "'", ',', ...], 'pos'),
#  (['a', 'frequent', 'error', 'is', 'the', ...], 'pos'),
#  (['very', 'few', 'people', 'would', 'be', 'unaware', ...], 'pos'),
#  (['let', 'me', 'start', 'off', 'by', 'saying', 'that', ...], 'pos'),
#  (['seen', 'september', '5', ',', '1998', 'at', '10', ...], 'pos'),
# ...
#  (['i', 'remember', 'seeing', 'the', 'trailer', 'of', ...], 'pos'),
#  (['quiz', 'show', ',', 'an', 'almost', 'perfectly', ...], 'pos'),
#  (['is', 'jimmy', 'stewart', 'the', 'greatest', 'actor', ...], 'pos'),
#  (['every', 'once', 'in', 'a', 'while', 'you', 'see', ...], 'pos'),
#  (['men', 'in', 'black', 'is', 'an', 'explosive', 'mix', ...], 'pos'),
#  (['ralph', 'fiennes', 'is', 'carving', 'out', 'a', ...], 'pos'),
#  (['in', 'october', 'of', '1962', 'the', 'united', ...], 'pos'),
#  (['true', 'faith', 'and', 'its', 'expression', ...], 'pos'),
#  (['when', 'a', 'someone', 'journeys', 'to', 'the', ...], 'pos'),
#  (['almost', 'a', 'full', 'decade', 'before', 'steven', ...], 'pos'),
#  (['in', 'these', 'days', 'of', 'overlong', 'movies', ...], 'pos'),
#  (['dark', 'city', 'is', 'such', 'a', 'rare', 'treat', ...], 'pos'),
#  (['anyone', 'who', 'saw', 'alan', 'rickman', "'", 's', ...], 'pos'),
#  (['i', 'want', 'to', 'correct', 'what', 'i', 'wrote', ...], 'pos'),
#  (['recently', 'i', 'read', '4', 'reviews', 'of', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['robocop', 'is', 'an', 'intelligent', 'science', ...], 'pos'),
#  (['probably', 'the', 'most', 'popular', 'and', ...], 'pos'),
#  (['cinema', 'has', 'been', 'around', 'for', 'about', ...], 'pos'),
#  (['it', "'", 's', 'no', 'secret', 'in', 'the', 'motion', ...], 'pos'),
#  (['when', 'andy', 'leaves', 'for', 'cowboy', 'camp', ...], 'pos'),
#  (['david', 'lynch', "'", 's', '"', 'blue', 'velvet', ...], 'pos'),
#  (['if', 'chris', 'farley', 'had', 'strapped', 'some', ...], 'pos'),
#  (['"', 'you', 'leave', 'little', 'notes', 'on', 'my', ...], 'pos'),
#  (['ingredients', ':', 'lost', 'parrot', 'trying', 'to', ...], 'pos'),
#  (['tempe', 'mills', 'cinema', ',', 'az', '--', 'this', ...], 'pos'),
#  (['there', 'is', 'nothing', 'like', 'american', ...], 'pos'),
#  (['john', 'von', 'neumann', ',', 'progenitor', 'of', ...], 'pos'),
#  (['as', 'the', 'small', 'boats', 'rock', 'slowly', ...], 'pos'),
#  (['"', 'the', 'faculty', ',', '"', 'the', 'heavily', ...], 'pos'),
#  (['the', 'central', 'focus', 'of', 'michael', ...], 'pos'),
#  (['after', 'the', 'average', 'mouse', 'hunt', ',', ...], 'pos'),
#  (['i', 'have', 'seen', 'several', '(', 'but', 'not', ...], 'pos'),
#  (['fritz', 'lang', "'", 's', 'first', 'american', ...], 'pos'),
#  (['veteran', 'actor', 'clint', 'eastwood', 'has', ...], 'pos'),
#  (['those', 'of', 'you', 'who', 'frequently', 'read', ...], 'pos'),
#  (['this', 'is', 'a', 'stagy', 'film', 'adapted', 'from', ...], 'pos'),
#  (['the', 'coen', 'brothers', 'are', 'back', 'again', ...], 'pos'),
#  (['contact', '(', 'pg', ')', 'there', "'", 's', 'a', ...], 'pos'),
#  (['satirical', 'films', 'usually', 'fall', 'into', ...], 'pos'),
#  (['after', 'sixteen', 'years', 'francis', 'ford', ...], 'pos'),
#  (['bruce', 'willis', 'is', 'a', 'type', '-', 'casted', ...], 'pos'),
#  (['there', 'must', 'be', 'some', 'unwritten', 'rule', ...], 'pos'),
#  (['did', 'claus', 'von', 'bulow', 'try', 'to', 'kill', ...], 'pos'),
#  (['driving', 'miss', 'daisy', 'takes', 'its', 'sweet', ...], 'pos'),
#  (['when', 'people', 'are', 'talking', 'about', 'good', ...], 'pos'),
#  (['note', ':', 'ordinarily', ',', 'moviereviews', '.', ...], 'pos'),
#  (['seen', 'april', '16', ',', '1999', 'at', '10', 'p', ...], 'pos'),
#  (['mars', 'attacks', '!', '(', '1996', ')', '-', 'c', ...], 'pos'),
#  (['when', 'i', 'was', 'asked', 'to', 'see', 'this', ...], 'pos'),
#  (['you', "'", 'd', 'think', 'it', 'would', 'be', 'easy', ...], 'pos'),
#  (['in', 'my', 'review', 'of', 'there', "'", 's', ...], 'pos'),
#  (['showgirls', 'is', 'the', 'second', 'major', 'outing', ...], 'pos'),
#  (['it', 'has', 'been', 'three', 'long', 'years', ...], 'pos'),
#  (['one', 'of', 'the', 'biggest', 'cliches', 'of', 'any', ...], 'pos'),
#  (['i', 'was', 'originally', 'going', 'to', 'give', ...], 'pos'),
#  (['an', 'unhappy', 'italian', 'housewife', ',', 'a', ...], 'pos'),
#  (['after', 'the', 'terminally', 'bleak', 'reservoir', ...], 'pos'),
#  (['upon', 'taking', 'a', 'seat', 'at', 'the', 'theater', ...], 'pos'),
#  (['in', 'may', 'of', '1977', ',', 'just', '2', 'years', ...], 'pos'),
#  (['`', 'strange', 'days', "'", 'chronicles', 'the', ...], 'pos'),
#  (['there', "'", 's', 'a', 'thin', 'line', 'between', ...], 'pos'),
#  (['it', 'was', 'only', 'a', 'matter', 'of', 'time', ...], 'pos'),
#  (['all', 'those', 'who', 'were', 'offended', 'by', ...], 'pos'),
#  (['albert', 'brooks', 'saves', 'the', 'day', ',', ...], 'pos'),
#  (['for', 'more', 'than', 'a', 'decade', ',', 'anjelica', ...], 'pos'),
#  (['razor', 'blade', 'smile', 'running', 'as', 'part', ...], 'pos'),
#  (['pitch', 'black', 'is', 'a', 'sheep', 'in', 'wolf', ...], 'pos'),
#  (['seen', 'february', '15', ',', '1998', 'on', 'home', ...], 'pos'),
#  (['"', 'sometimes', 'the', "'", 'green', 'mile', "'", ...], 'pos'),
#  (['i', 'guess', 'there', 'are', 'those', 'who', 'have', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['in', 'chocolat', ',', 'a', 'chocolate', 'shop', ...], 'pos'),
#  (['while', 'alex', 'browning', '(', 'devon', 'sawa', ...], 'pos'),
#  (['assume', 'nothing', '.', 'the', 'phrase', 'is', ...], 'pos'),
#  (['the', 'question', 'isn', "'", 't', 'why', 'has', ...], 'pos'),
#  (['let', "'", 's', 'face', 'it', ':', 'since', ...], 'pos'),
#  (['if', 'beavis', 'and', 'butthead', 'had', 'a', ...], 'pos'),
#  (['the', 'small', '-', 'scale', 'film', ',', 'in', ...], 'pos'),
#  (['warren', 'beatty', "'", 's', '"', 'bulworth', '"', ...], 'pos'),
#  (['when', 'i', 'saw', 'the', 'trailer', 'for', 'this', ...], 'pos'),
#  (['plot', ':', 'a', 'young', 'recruit', 'gets', ...], 'pos'),
#  (['bruce', 'lee', 'was', 'a', 'bigger', '-', 'than', ...], 'pos'),
#  (['clint', 'eastwood', ',', 'in', 'his', 'ripe', 'old', ...], 'pos'),
#  (['meet', 'joe', 'black', 'is', 'your', 'classic', ...], 'pos'),
#  (['buffalo', '?', '66', 'is', 'a', 'very', 'rarely', ...], 'pos'),
#  (['after', 'being', 'hypnotized', ',', 'a', 'man', ...], 'pos'),
#  (['being', 'the', 'self', '-', 'proclaimed', ...], 'pos'),
#  (['my', 'summer', 'was', 'recently', 'saved', 'by', ...], 'pos'),
#  (['so', 'many', 'students', 'strive', 'to', 'get', ...], 'pos'),
#  (['available', 'for', 'rental', '-', 'october', '12', ...], 'pos'),
#  (['my', 'filmcritic', '.', 'com', 'colleague', 'norm', ...], 'pos'),
#  (['what', 'i', 'look', 'for', 'in', 'a', 'movie', 'is', ...], 'pos'),
#  (['mike', 'myers', ',', 'you', 'certainly', 'did', ...], 'pos'),
#  (['it', 'is', 'with', 'hesitance', 'that', 'i', 'call', ...], 'pos'),
#  (['the', 'verdict', ':', 'spine', '-', 'chilling', ...], 'pos'),
#  (['an', 'indian', 'runner', 'was', 'more', 'than', 'a', ...], 'pos'),
#  (['seen', 'july', '8', ',', '1998', 'at', 'the', ...], 'pos'),
#  (['not', 'since', 'attending', 'an', 'ingmar', ...], 'pos'),
#  (['after', 'a', 'successful', 'run', 'in', 'australia', ...], 'pos'),
#  (['every', 'once', 'in', 'a', 'while', ',', 'a', 'film', ...], 'pos'),
#  (['"', 'through', 'a', 'spyglass', ',', 'i', 'could', ...], 'pos'),
#  (['wong', 'kar', '-', 'wei', "'", 's', '"', 'fallen', ...], 'pos'),
#  (['city', 'of', 'angels', 'is', 'the', 'kind', 'of', ...], 'pos'),
#  (['have', 'you', 'ever', 'wondered', 'if', 'death', ...], 'pos'),
#  (['originally', 'entitled', 'dancing', 'about', ...], 'pos'),
#  (['"', 'well', 'this', 'is', 'not', 'mission', ':', ...], 'pos'),
#  (['robert', 'redford', 'is', 'very', 'good', 'at', ...], 'pos'),
#  (['in', 'roger', 'michell', "'", 's', 'romantic', ...], 'pos'),
#  (['ingredients', ':', 'man', 'with', 'amnesia', 'who', ...], 'pos'),
#  (['every', 'once', 'in', 'a', 'while', ',', 'when', ...], 'pos'),
#  (['usually', 'when', 'one', 'is', 'debating', 'who', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['"', 'i', 'know', 'what', 'you', 'did', 'last', ...], 'pos'),
#  (['labelling', 'is', 'sometimes', 'everything', '.', ...], 'pos'),
#  (['for', 'those', 'who', 'associate', 'italian', ...], 'pos'),
#  (['the', 'word', "'", 'rest', "'", 'in', 'the', 'title', ...], 'pos'),
#  (['airplane', '!', 'is', 'considered', 'among', 'many', ...], 'pos'),
#  (['this', 'is', 'the', 'movie', 'not', 'the', 'perfume', ...], 'pos'),
#  (['the', 'farrelly', 'brothers', "'", 'third', 'film', ...], 'pos'),
#  (['when', 'jim', 'henson', 'passed', 'away', ',', 'he', ...], 'pos'),
#  (['bob', 'the', 'happy', 'bastard', "'", 's', 'quickie', ...], 'pos'),
#  (['the', 'laserman', ':', 'somehow', 'the', 'title', ...], 'pos'),
#  (['imagine', 'this', '.', 'you', "'", 're', 'given', ...], 'pos'),
#  (['so', 'here', 'is', 'the', 'second', 'of', '1999', ...], 'pos'),
#  (['apollo', '13', 'is', 'simply', 'one', 'of', 'the', ...], 'pos'),
#  (['in', '_daylight_', ',', 'sylvester', 'stallone', ...], 'pos'),
#  (['perhaps', 'the', 'most', 'dramatic', 'changes', 'in', ...], 'pos'),
#  (['let', 'me', 'open', 'this', 'one', 'with', 'a', ...], 'pos'),
#  (['carla', 'gugino', 'graduates', 'from', 'high', ...], 'pos'),
#  (['the', 'soldiers', 'of', 'three', 'kings', 'have', ...], 'pos'),
#  (['bill', 'condon', "'", 's', '"', 'gods', 'and', ...], 'pos'),
#  (['i', 'must', 'admit', 'that', 'i', 'was', 'a', 'tad', ...], 'pos'),
#  (['a', 'cinematic', 'version', 'of', 'one', 'of', ...], 'pos'),
#  (['the', 'only', 'historical', 'figure', 'that', 'has', ...], 'pos'),
#  (['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...], 'neg'),
#  (['the', 'happy', 'bastard', "'", 's', 'quick', 'movie', ...], 'neg'),
#  (['it', 'is', 'movies', 'like', 'these', 'that', 'make', ...], 'neg'),
#  (['"', 'quest', 'for', 'camelot', '"', 'is', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'a', 'mentally', 'unstable', 'man', ...], 'neg'),
#  (['capsule', ':', 'in', '2176', 'on', 'the', 'planet', ...], 'neg'),
#  (['so', 'ask', 'yourself', 'what', '"', '8mm', '"', '(', ...], 'neg'),
#  (['that', "'", 's', 'exactly', 'how', 'long', 'the', ...], 'neg'),
#  (['call', 'it', 'a', 'road', 'trip', 'for', 'the', ...], 'neg'),
#  (['plot', ':', 'a', 'young', 'french', 'boy', 'sees', ...], 'neg'),
#  (['best', 'remembered', 'for', 'his', 'understated', ...], 'neg'),
#  (['janeane', 'garofalo', 'in', 'a', 'romantic', ...], 'neg'),
#  (['and', 'now', 'the', 'high', '-', 'flying', 'hong', ...], 'neg'),
#  (['a', 'movie', 'like', 'mortal', 'kombat', ':', ...], 'neg'),
#  (['she', 'was', 'the', 'femme', 'in', '"', 'la', ...], 'neg'),
#  (['john', 'carpenter', 'makes', 'b', '-', 'movies', '.', ...], 'neg'),
#  (['i', "'", 'm', 'really', 'starting', 'to', 'wonder', ...], 'neg'),
#  (['so', 'what', 'do', 'you', 'get', 'when', 'you', ...], 'neg'),
#  (['the', 'law', 'of', 'crowd', 'pleasing', 'romantic', ...], 'neg'),
#  (['mighty', 'joe', 'young', 'blunders', 'about', 'for', ...], 'neg'),
#  (['"', 'spawn', '"', 'features', 'good', 'guys', ',', ...], 'neg'),
#  (['"', 'in', 'dreams', '"', 'might', 'keep', 'you', ...], 'neg'),
#  (['"', 'knock', 'off', '"', 'is', 'exactly', 'that', ...], 'neg'),
#  (['"', 'snake', 'eyes', '"', 'is', 'the', 'most', ...], 'neg'),
#  (['forgive', 'the', 'fevered', 'criticism', 'but', ...], 'neg'),
#  (['one', 'might', 'expect', 'a', 'cathartic', 'viewing', ...], 'neg'),
#  (['america', 'loves', 'convenience', '.', 'after', ...], 'neg'),
#  (['reindeer', 'games', 'is', 'easily', 'the', 'worst', ...], 'neg'),
#  (['a', 'follow', '-', 'up', 'to', 'disney', "'", 's', ...], 'neg'),
#  (['one', '-', 'sided', '"', 'doom', 'and', 'gloom', '"', ...], 'neg'),
#  (['play', 'it', 'to', 'the', 'bone', ',', 'the', ...], 'neg'),
#  (['some', 'movies', 'i', 'should', 'just', 'skip', '.', ...], 'neg'),
#  (['hong', 'kong', 'cinema', 'has', 'been', 'going', ...], 'neg'),
#  (['i', 'wish', 'i', 'could', 'have', 'been', 'in', ...], 'neg'),
#  (['if', 'you', "'", 're', 'into', 'watching', 'near', ...], 'neg'),
#  (['sean', 'connery', 'stars', 'as', 'a', 'harvard', ...], 'neg'),
#  (['among', 'multitude', 'of', 'erotic', 'thrillers', ...], 'neg'),
#  (['"', 'lake', 'placid', '"', 'marks', 'yet', 'another', ...], 'neg'),
#  (['capsule', ':', 'where', 'are', 'you', 'tonight', ',', ...], 'neg'),
#  (['the', 'classic', 'story', '&', 'the', 'production', ...], 'neg'),
#  (['lengthy', 'and', 'lousy', 'are', 'two', 'words', ...], 'neg'),
#  (['out', 'of', 'sight', 'director', 'steven', ...], 'neg'),
#  (['a', 'pseudo', '-', 'intellectual', 'film', 'about', ...], 'neg'),
#  (['"', 'party', 'camp', ',', '"', 'is', 'one', 'of', ...], 'neg'),
#  (['i', "'", 'm', 'currently', 'accepting', 'all', ...], 'neg'),
#  (['when', 'it', 'comes', 'to', 'the', 'average', ...], 'neg'),
#  (['all', 'through', 'its', 'production', 'and', 'into', ...], 'neg'),
#  (['instinct', 'is', 'the', 'kind', 'of', 'movie', ...], 'neg'),
#  (['sydney', 'lumet', 'is', 'the', 'director', 'whose', ...], 'neg'),
#  (['"', 'the', 'world', 'on', 'land', '--', 'it', "'", ...], 'neg'),
#  (['my', 'giant', 'is', 'two', 'movies', 'for', 'the', ...], 'neg'),
#  (['talk', 'about', 'a', 'movie', 'that', 'seemed', ...], 'neg'),
#  (['this', 'feature', 'is', 'like', 'a', 'double', ...], 'neg'),
#  (['one', 'of', 'the', 'responses', 'those', 'that', ...], 'neg'),
#  (['has', 'it', 'really', 'been', 'two', 'decades', ...], 'neg'),
#  (['funny', 'how', 'your', 'expectations', 'can', 'be', ...], 'neg'),
#  (['unfortunately', 'it', 'doesn', "'", 't', 'get', ...], 'neg'),
#  (['supposedly', 'based', 'on', 'a', 'true', 'story', ...], 'neg'),
#  (['of', 'course', 'i', 'knew', 'this', 'going', 'in', ...], 'neg'),
#  (['louie', 'is', 'a', 'trumpeter', 'swan', 'with', 'no', ...], 'neg'),
#  (['one', 'of', 'the', 'most', 'respected', 'names', ...], 'neg'),
#  (["'", 'traffic', 'violation', "'", 'dr', '.', 'daniel', ...], 'neg'),
#  (['there', 'are', 'two', 'things', 'the', 'american', ...], 'neg'),
#  (['would', 'you', 'believe', '--', 'in', 'real', 'life', ...], 'neg'),
#  (['rated', ':', 'r', 'for', 'strong', 'violence', ',', ...], 'neg'),
#  (['movie', 'reviewers', 'have', 'an', 'obligation', ...], 'neg'),
#  (['mr', '.', 'nice', 'guy', 'is', 'the', 'latest', ...], 'neg'),
#  (['"', 'first', 'rule', 'of', 'fight', 'club', 'is', ...], 'neg'),
#  (['note', 'to', 'screenwriters', 'and', 'self', ':', ...], 'neg'),
#  (['the', 'recent', 'onslaught', 'of', 'film', 'noir', ...], 'neg'),
#  (['it', 'rocks', '-', 'actually', ',', 'lots', 'of', ...], 'neg'),
#  (['there', "'", 's', 'a', '1', ',', '000', '-', 'foot', ...], 'neg'),
#  (['"', 'there', 'will', 'be', 'another', ',', '"', ...], 'neg'),
#  (['late', 'in', 'down', 'to', 'you', ',', 'the', 'lead', ...], 'neg'),
#  (['for', 'better', 'or', 'worse', ',', 'the', ...], 'neg'),
#  (['it', 'was', 'with', 'great', 'anticipation', 'that', ...], 'neg'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'neg'),
#  (['ahh', 'yes', '.', 'the', 'teenage', 'romance', '.', ...], 'neg'),
#  (['"', 'virus', '"', 'is', 'the', 'type', 'of', ...], 'neg'),
#  (['over', '40', 'years', 'ago', ',', 'a', 'japanese', ...], 'neg'),
#  (['before', 'the', 'remake', 'of', 'psycho', 'appears', ...], 'neg'),
#  (['coinciding', 'with', 'the', 'emerging', 'popularity', ...], 'neg'),
#  (['edward', 'burns', 'tackles', 'his', 'third', ...], 'neg'),
#  (['i', 'don', "'", 't', 'expect', 'much', 'from', ...], 'neg'),
#  (['brian', 'de', 'palma', ',', 'the', 'director', 'who', ...], 'neg'),
#  (['it', "'", 's', 'now', 'the', 'anniversary', 'of', ...], 'neg'),
#  (['lucas', 'was', 'wise', 'to', 'start', 'his', 'star', ...], 'neg'),
#  (['five', 'girls', 'spend', 'a', 'day', 'in', 'a', ...], 'neg'),
#  (['the', 'first', 'film', 'produced', 'by', 'adam', ...], 'neg'),
#  (['tectonic', 'plates', 'is', 'an', 'incredibly', ...], 'neg'),
#  (['various', 'films', 'seen', 'at', 'the', 'seattle', ...], 'neg'),
#  (['capsule', ':', 'the', 'weakest', 'and', 'least', ...], 'neg'),
#  (['"', 'from', 'the', 'director', 'of', '"', 'the', ...], 'neg'),
#  (['numerous', 'comparisons', 'can', 'be', 'made', ...], 'neg'),
#  (['a', 'documentary', 'from', 'the', 'twin', 'hughes', ...], 'neg'),
#  (['gord', 'brody', '(', 'tom', 'green', ')', 'is', 'an', ...], 'neg'),
#  (['much', 'ado', 'about', 'nothing', '.', 'ah', ',', ...], 'neg'),
#  (['another', 'formula', "'", 'feel', 'good', "'", ...], 'neg'),
#  (['"', 'love', 'to', 'kill', '"', 'starts', 'off', ...], 'neg'),
#  (['whether', 'you', 'like', 'the', 'beatles', 'or', ...], 'neg'),
#  ...]

# %% [markdown]
# #### ❓Exercise 2. Create the testing data by combining the remaining 100 rows of the positive reviews and the remaining 100 rows of negative reviews

# %%
testing_pos_fields = movie_reviews.fileids("pos")[training_set_size:]
testing_neg_fields = movie_reviews.fileids("neg")[training_set_size:]

testing_data = [(movie_reviews.words(fileid), "pos") for fileid in testing_pos_fields] + [(movie_reviews.words(fileid),"neg") for fileid in testing_neg_fields]

# %% [markdown]
# ===

# %%
#there should be 100 + 100 = 200 rows in the testing set
print(len(testing_data))
testing_data
# Out:
# 200
# [(['in', '1912', ',', 'a', 'ship', 'set', 'sail', 'on', ...], 'pos'),
#  (['the', 'start', 'of', 'this', 'movie', 'reminded', ...], 'pos'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'pos'),
#  (['robert', 'altman', "'", 's', 'cookie', "'", 's', ...], 'pos'),
#  (['well', 'i', "'", 'll', 'be', 'damned', '.', '.', '.', ...], 'pos'),
#  (['hedwig', '(', 'john', 'cameron', 'mitchell', ')', ...], 'pos'),
#  (['niagara', 'niagara', '(', 'r', ')', 'bob', 'gosse', ...], 'pos'),
#  (['notice', ':', 'this', 'is', 'a', 'review', 'and', ...], 'pos'),
#  (['i', 'actually', 'am', 'a', 'fan', 'of', 'the', ...], 'pos'),
#  (['gere', ',', 'willis', ',', 'poitier', 'chase', ...], 'pos'),
#  (['it', "'", 's', 'terribly', 'unfortunate', 'that', ...], 'pos'),
#  (['usually', 'when', 'a', 'blockbuster', 'comes', 'out', ...], 'pos'),
#  (['review', '-', 'peter', 'jackson', "'", 's', 'the', ...], 'pos'),
#  (['before', 'you', 'read', 'my', 'review', ',', 'you', ...], 'pos'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'pos'),
#  (['what', 'do', 'you', 'get', 'when', 'you', 'combine', ...], 'pos'),
#  (['martin', 'scorsese', "'", 's', 'triumphant', ...], 'pos'),
#  (['plot', ':', 'a', 'dude', 'and', 'his', 'brother', ...], 'pos'),
#  (['wyatt', 'earp', 'has', 'a', 'lot', 'to', 'tell', ...], 'pos'),
#  (['when', 'i', 'first', 'heard', 'that', 'kevin', ...], 'pos'),
#  (['in', 'zoolander', ',', 'the', 'world', "'", 's', ...], 'pos'),
#  (['originally', 'titled', "'", 'don', "'", 't', 'lose', ...], 'pos'),
#  (['if', 'there', 'is', 'one', 'thing', 'that', ...], 'pos'),
#  (['ingredients', ':', 'down', '-', 'on', '-', 'his', ...], 'pos'),
#  (['the', 'most', 'amazing', 'thing', 'about', 'paul', ...], 'pos'),
#  (['contact', 'is', 'a', 'film', 'that', 'tries', 'to', ...], 'pos'),
#  (['billy', 'bob', 'thornton', ',', 'who', 'had', 'a', ...], 'pos'),
#  (['tibet', 'has', 'entered', 'the', 'american', ...], 'pos'),
#  (['i', 'swear', 'i', 'have', 'seen', 'the', 'edge', ...], 'pos'),
#  (['one', 'of', 'the', 'more', 'unusual', 'and', ...], 'pos'),
#  (['there', 'are', 'some', 'works', 'of', 'art', 'that', ...], 'pos'),
#  (['like', 'the', 'great', 'musical', 'pieces', 'of', ...], 'pos'),
#  (['armageddon', ',', 'in', 'itself', ',', 'symbolizes', ...], 'pos'),
#  (['this', 'is', 'one', 'of', 'the', 'most', 'funny', ...], 'pos'),
#  (['not', 'too', 'many', 'people', 'know', 'who', ...], 'pos'),
#  (['when', 'i', 'initially', 'set', 'out', 'to', ...], 'pos'),
#  (['it', "'", 's', 'tough', 'to', 'really', 'say', ...], 'pos'),
#  (['synopsis', ':', 'as', 'a', 'response', 'to', ...], 'pos'),
#  (['the', 'idea', 'at', 'the', 'center', 'of', 'the', ...], 'pos'),
#  (['scream', '2', ',', 'like', 'its', 'predecessor', ',', ...], 'pos'),
#  (['when', 'i', 'first', 'saw', 'the', 'previews', 'for', ...], 'pos'),
#  (['ingredients', ':', 'james', 'bond', ',', 'scuba', ...], 'pos'),
#  (['it', 'is', 'always', 'refreshing', 'to', 'see', 'a', ...], 'pos'),
#  (['if', 'you', 'thought', 'baz', 'luhrmann', "'", 's', ...], 'pos'),
#  (['meteor', 'threat', 'set', 'to', 'blow', 'away', ...], 'pos'),
#  (['there', 'is', 'a', 'striking', 'scene', 'early', ...], 'pos'),
#  (['star', 'wars', ':', 'episode', '1', '-', 'the', ...], 'pos'),
#  (['the', 'premise', 'is', 'simple', ',', 'if', 'not', ...], 'pos'),
#  (['any', 'movie', 'about', 'the', 'underground', ...], 'pos'),
#  (['steve', 'martin', 'took', 'an', 'extended', ...], 'pos'),
#  (['>', 'from', 'the', 'man', 'who', 'presented', 'us', ...], 'pos'),
#  (['how', 'many', 'of', 'us', 'would', 'become', ...], 'pos'),
#  (['director', 'dominic', 'sena', '(', 'who', 'made', ...], 'pos'),
#  (['books', 'could', 'be', ',', 'and', 'indeed', 'have', ...], 'pos'),
#  (['eddie', 'murphy', 'has', 'had', 'his', 'share', 'of', ...], 'pos'),
#  (['cinematically', 'speaking', ',', 'gordon', 'parks', ...], 'pos'),
#  (['uncompromising', 'french', 'director', 'robert', ...], 'pos'),
#  (['capsule', ':', 'the', 'best', 'place', 'to', 'start', ...], 'pos'),
#  (['the', 'calendar', 'year', 'has', 'not', 'even', ...], 'pos'),
#  (['an', 'entertaining', '2', 'hours', 'awaits', 'the', ...], 'pos'),
#  (['gordon', 'fleming', '(', 'peter', 'mullan', ')', ...], 'pos'),
#  (['the', 'latest', 'epos', 'from', 'lars', 'is', 'a', ...], 'pos'),
#  (['anastasia', 'contains', 'something', 'that', 'has', ...], 'pos'),
#  (['i', 'can', 'hear', 'the', 'question', 'already', '.', ...], 'pos'),
#  (['you', "'", 've', 'got', 'to', 'think', 'twice', ...], 'pos'),
#  (['in', 'many', 'ways', ',', '"', 'twotg', '"', 'does', ...], 'pos'),
#  (['marie', '(', 'charlotte', 'rampling', ',', '"', ...], 'pos'),
#  (['is', 'it', 'just', 'me', ',', 'or', 'have', 'disney', ...], 'pos'),
#  (['insane', '(', 'but', 'inspired', ')', 'musical', ...], 'pos'),
#  (['allen', ',', 'star', 'of', 'many', 'a', 'brian', ...], 'pos'),
#  (['synopsis', ':', 'in', 'phantom', 'menace', 'the', ...], 'pos'),
#  (['at', 'one', 'point', 'during', 'brian', 'de', ...], 'pos'),
#  (['for', 'any', 'groom', 'on', 'the', 'verge', 'of', ...], 'pos'),
#  (['i', 'like', 'movies', 'with', 'albert', 'brooks', ...], 'pos'),
#  (['(', 'note', ':', 'there', 'are', 'spoilers', ...], 'pos'),
#  (['martin', 'scorsese', "'", 's', 'films', 'used', 'to', ...], 'pos'),
#  (['robert', 'redford', "'", 's', 'a', 'river', 'runs', ...], 'pos'),
#  (['richard', 'gere', 'is', 'not', 'one', 'of', 'my', ...], 'pos'),
#  (['"', 'when', 'you', 'get', 'out', 'of', 'jail', ',', ...], 'pos'),
#  (['let', "'", 's', 'say', 'you', 'live', 'at', 'the', ...], 'pos'),
#  (['in', 'this', 'good', 'natured', ',', 'pleasent', ...], 'pos'),
#  (['"', 'no', 'man', 'is', 'an', 'island', ',', '"', ...], 'pos'),
#  (['i', 'rented', 'this', 'movie', 'with', 'very', ...], 'pos'),
#  (['few', 'films', 'in', '1999', 'have', 'divided', ...], 'pos'),
#  (['now', 'that', '"', 'boogie', 'nights', '"', 'has', ...], 'pos'),
#  (['this', 'has', 'been', 'an', 'extraordinary', 'year', ...], 'pos'),
#  (['i', 'think', 'the', 'first', 'thing', 'this', ...], 'pos'),
#  (['trees', 'lounge', 'is', 'the', 'directoral', 'debut', ...], 'pos'),
#  (['i', 'wish', 'i', 'could', 'say', 'that', 'there', ...], 'pos'),
#  (['lisa', 'cholodenko', "'", 's', '"', 'high', 'art', ...], 'pos'),
#  (['the', 'relaxed', 'dude', 'rides', 'a', 'roller', ...], 'pos'),
#  (['i', 'don', "'", 't', 'box', 'with', 'kid', 'gloves', ...], 'pos'),
#  (['here', 'is', 'a', 'film', 'that', 'is', 'so', ...], 'pos'),
#  (['plot', ':', 'this', 'movie', 'takes', 'place', ...], 'pos'),
#  (['a', 'thriller', 'set', 'in', 'modern', 'day', ...], 'pos'),
#  (['wow', '!', 'what', 'a', 'movie', '.', 'it', "'", 's', ...], 'pos'),
#  (['richard', 'gere', 'can', 'be', 'a', 'commanding', ...], 'pos'),
#  (['glory', '--', 'starring', 'matthew', 'broderick', ...], 'pos'),
#  (['steven', 'spielberg', "'", 's', 'second', 'epic', ...], 'pos'),
#  (['truman', '(', '"', 'true', '-', 'man', '"', ')', ...], 'pos'),
#  (['there', 'may', 'not', 'be', 'a', 'critic', 'alive', ...], 'neg'),
#  (['renee', 'zellweger', 'stars', 'as', 'sonia', ',', ...], 'neg'),
#  (['there', "'", 're', 'so', 'many', 'things', 'to', ...], 'neg'),
#  (['don', "'", 't', 'let', 'this', 'movie', 'fool', ...], 'neg'),
#  (['it', "'", 's', 'a', 'good', 'thing', 'most', ...], 'neg'),
#  (['in', 'the', 'year', '2029', ',', 'captain', 'leo', ...], 'neg'),
#  (['writing', 'a', 'screenplay', 'for', 'a', 'thriller', ...], 'neg'),
#  (['all', 'right', ',', 'all', 'right', ',', 'we', 'get', ...], 'neg'),
#  (['teenagers', 'have', 'a', 'lot', 'of', 'power', 'in', ...], 'neg'),
#  (['walken', 'stars', 'as', 'a', 'mobster', 'who', 'is', ...], 'neg'),
#  (['>', 'from', 'writer', 'and', 'director', 'darren', ...], 'neg'),
#  (['well', 'there', 'goes', 'another', 'one', '.', ...], 'neg'),
#  (['my', 'inner', 'flag', 'was', 'at', 'half', '-', ...], 'neg'),
#  (['frank', 'detorri', "'", 's', '(', 'bill', 'murray', ...], 'neg'),
#  (['woof', '!', 'too', 'bad', 'that', 'leap', 'of', ...], 'neg'),
#  (['there', "'", 's', 'only', 'one', 'presidential', ...], 'neg'),
#  (['ah', ',', 'and', '1999', 'was', 'going', 'along', ...], 'neg'),
#  (['michael', 'robbins', "'", 'hardball', 'is', 'quite', ...], 'neg'),
#  (['you', 'know', 'something', ',', 'christmas', 'is', ...], 'neg'),
#  (['in', 'the', 'mid', '-', '1980s', ',', 'following', ...], 'neg'),
#  (['susan', 'granger', "'", 's', 'review', 'of', '"', ...], 'neg'),
#  (['note', ':', 'some', 'may', 'consider', 'portions', ...], 'neg'),
#  (['stallone', 'attempts', 'to', "'", 'act', "'", 'in', ...], 'neg'),
#  (['the', 'first', 'species', 'was', 'a', 'moderately', ...], 'neg'),
#  (['a', 'number', 'of', 'critics', 'have', 'decided', ...], 'neg'),
#  (['everybody', 'in', 'this', 'film', "'", 's', ...], 'neg'),
#  (['star', 'wars', ':', '?', 'episode', 'i', '--', 'the', ...], 'neg'),
#  (['the', 'lives', 'of', 'older', 'people', 'in', 'the', ...], 'neg'),
#  (['martial', 'arts', 'master', 'steven', 'seagal', '(', ...], 'neg'),
#  (['arye', 'cross', 'and', 'courteney', 'cox', 'star', ...], 'neg'),
#  (['_soldier_', 'is', 'hands', 'down', 'one', 'of', ...], 'neg'),
#  (['it', "'", 's', 'a', 'sad', 'state', 'of', 'affairs', ...], 'neg'),
#  (['birthdays', 'often', 'cause', 'individuals', 'to', ...], 'neg'),
#  (['m', ':', 'i', '-', '2', ',', 'the', 'sequel', 'to', ...], 'neg'),
#  (['ex', '-', 'universal', 'soldier', 'luc', 'has', 'to', ...], 'neg'),
#  (['the', 'plot', 'of', 'big', 'momma', "'", 's', ...], 'neg'),
#  (['starring', 'william', 'baldwin', ';', 'cindy', ...], 'neg'),
#  (['take', 'a', 'look', 'at', 'the', 'following', ...], 'neg'),
#  (['synopsis', ':', 'a', 'maniac', ',', 'crazed', 'by', ...], 'neg'),
#  (['post', '-', 'chasing', 'amy', ',', 'a', 'slew', 'of', ...], 'neg'),
#  (['yet', 'another', 'brainless', 'teen', 'flick', ',', ...], 'neg'),
#  (['set', 'in', 'harlem', 'during', 'the', 'great', ...], 'neg'),
#  (['at', 'first', 'glance', ',', 'i', 'thought', 'that', ...], 'neg'),
#  (['this', 'movie', 'stinks', '!', 'although', 'it', ...], 'neg'),
#  (['"', 'it', 'was', 'not', 'scary', '.', '"', 'these', ...], 'neg'),
#  (['perhaps', 'best', 'remembered', 'as', 'the', ...], 'neg'),
#  (['summer', 'movies', 'are', ',', 'by', 'nature', ',', ...], 'neg'),
#  (['what', 'were', 'they', 'thinking', '?', 'nostalgia', ...], 'neg'),
#  (['and', 'just', 'when', 'you', 'thought', 'joblo', ...], 'neg'),
#  (['`', 'bats', "'", 'is', 'an', 'insulting', 'slap', ...], 'neg'),
#  (['the', 'most', 'interesting', 'part', 'of', '"', ...], 'neg'),
#  (['the', 'film', 'may', 'be', 'called', 'mercury', ...], 'neg'),
#  (['"', 'alcohol', 'and', 'drugs', '=', 'bad', '.', ...], 'neg'),
#  (['capsule', ':', 'combine', 'one', 'quart', 'of', ...], 'neg'),
#  (['a', 'new', 'entry', 'in', 'the', '"', 'revisionist', ...], 'neg'),
#  (['words', 'i', 'thought', 'i', "'", 'd', 'never', ...], 'neg'),
#  (['godzilla', 'is', 'the', 'ultimate', 'culmination', ...], 'neg'),
#  (['recently', 'one', 'night', 'a', 'young', 'director', ...], 'neg'),
#  (['in', 'times', 'of', 'crisis', 'people', 'are', ...], 'neg'),
#  (['"', 'virus', '"', 'is', 'a', 'monster', 'movie', ...], 'neg'),
#  (['dr', '.', 'alan', 'grant', '(', 'sam', 'neill', ',', ...], 'neg'),
#  (['barb', 'wire', ',', 'pamela', 'anderson', 'lee', "'", ...], 'neg'),
#  (['humanities', 'quest', 'for', 'knowledge', 'never', ...], 'neg'),
#  (['absolute', 'power', ',', 'the', 'new', 'film', ...], 'neg'),
#  (['ever', 'feel', 'you', "'", 're', 'spending', 'your', ...], 'neg'),
#  (['"', 'book', '"', 'should', 'have', 'remained', 'in', ...], 'neg'),
#  (['warren', 'beatty', ',', 'diane', 'keaton', ',', ...], 'neg'),
#  (['the', 'crown', 'jewel', 'of', '1970', "'", 's', ...], 'neg'),
#  (['while', 'watching', 'loser', ',', 'it', 'occurred', ...], 'neg'),
#  (['capsule', ':', 'john', 'the', 'baptist', 'is', ...], 'neg'),
#  (['the', '"', 'disney', 'stick', '-', 'to', '-', 'what', ...], 'neg'),
#  (['as', 'the', 'twin', 'surfer', 'dudes', ',', 'stew', ...], 'neg'),
#  (["'", 'bicentennial', 'man', "'", 'is', 'a', 'family', ...], 'neg'),
#  (['in', 'the', 'continuation', 'of', 'warner', ...], 'neg'),
#  (['long', 'ago', ',', 'films', 'were', 'constructed', ...], 'neg'),
#  (['stars', ':', 'armand', 'assante', '(', 'mike', ...], 'neg'),
#  (['nostalgia', 'for', 'the', '70s', 'continues', ',', ...], 'neg'),
#  (['i', 'saw', 'this', 'film', 'on', 'christmas', 'day', ...], 'neg'),
#  (['anna', 'and', 'the', 'king', 'is', 'at', 'least', ...], 'neg'),
#  (['robin', 'hood', ':', 'men', 'in', 'tights', 'is', ...], 'neg'),
#  (['with', 'his', 'successful', 'books', 'and', 'movies', ...], 'neg'),
#  (['director', 'luis', 'mandoki', "'", 's', 'last', ...], 'neg'),
#  (['i', 'remember', 'really', 'enjoying', 'this', ...], 'neg'),
#  (['tommy', 'lee', 'jones', 'chases', 'an', 'innocent', ...], 'neg'),
#  (['while', 'i', 'am', 'not', 'fond', 'of', 'any', ...], 'neg'),
#  (['boy', ',', 'what', 'a', 'great', 'movie', '!', '!', ...], 'neg'),
#  (['there', 'are', 'those', 'of', 'us', 'who', 'think', ...], 'neg'),
#  (['please', 'don', "'", 't', 'mind', 'this', 'windbag', ...], 'neg'),
#  (['this', 'movie', 'is', 'written', 'by', 'the', 'man', ...], 'neg'),
#  (['in', 'a', 'typical', 'cinematic', 'high', 'school', ...], 'neg'),
#  (['man', ',', 'this', 'was', 'one', 'wierd', 'movie', ...], 'neg'),
#  (['the', 'king', 'and', 'i', ',', 'a', 'warner', ...], 'neg'),
#  (['synopsis', ':', 'cro', '-', 'magnon', 'ayla', ...], 'neg'),
#  (['salaries', 'of', 'hollywood', 'top', 'actors', 'are', ...], 'neg'),
#  (['movies', 'like', 'six', 'days', ',', 'seven', ...], 'neg'),
#  (['if', 'anything', ',', '"', 'stigmata', '"', 'should', ...], 'neg'),
#  (['john', 'boorman', "'", 's', '"', 'zardoz', '"', 'is', ...], 'neg'),
#  (['the', 'kids', 'in', 'the', 'hall', 'are', 'an', ...], 'neg'),
#  (['there', 'was', 'a', 'time', 'when', 'john', ...], 'neg'),
#  (['two', 'party', 'guys', 'bob', 'their', 'heads', 'to', ...], 'neg')]

# %% [markdown]
# ## Generate the Feature Vector

# %% [markdown]
# We will just create Bag of Word (BoW) model. I.e. using the words as the features. We will adopt the **term presence** approach (i.e. capture whether a term/word exist).

# %%
def extract_unigram_feature(words):
    #each word is a feature
    #there are many entries so need to use dict() instead of {} literal
    return dict((word, True) for word in words)

# %%
extract_unigram_feature(training_data[0][0])
# Out:
# {'films': True,
#  'adapted': True,
#  'from': True,
#  'comic': True,
#  'books': True,
#  'have': True,
#  'had': True,
#  'plenty': True,
#  'of': True,
#  'success': True,
#  ',': True,
#  'whether': True,
#  'they': True,
#  "'": True,
#  're': True,
#  'about': True,
#  'superheroes': True,
#  '(': True,
#  'batman': True,
#  'superman': True,
#  'spawn': True,
#  ')': True,
#  'or': True,
#  'geared': True,
#  'toward': True,
#  'kids': True,
#  'casper': True,
#  'the': True,
#  'arthouse': True,
#  'crowd': True,
#  'ghost': True,
#  'world': True,
#  'but': True,
#  'there': True,
#  's': True,
#  'never': True,
#  'really': True,
#  'been': True,
#  'a': True,
#  'book': True,
#  'like': True,
#  'hell': True,
#  'before': True,
#  '.': True,
#  'for': True,
#  'starters': True,
#  'it': True,
#  'was': True,
#  'created': True,
#  'by': True,
#  'alan': True,
#  'moore': True,
#  'and': True,
#  'eddie': True,
#  'campbell': True,
#  'who': True,
#  'brought': True,
#  'medium': True,
#  'to': True,
#  'whole': True,
#  'new': True,
#  'level': True,
#  'in': True,
#  'mid': True,
#  '80s': True,
#  'with': True,
#  '12': True,
#  '-': True,
#  'part': True,
#  'series': True,
#  'called': True,
#  'watchmen': True,
#  'say': True,
#  'thoroughly': True,
#  'researched': True,
#  'subject': True,
#  'jack': True,
#  'ripper': True,
#  'would': True,
#  'be': True,
#  'saying': True,
#  'michael': True,
#  'jackson': True,
#  'is': True,
#  'starting': True,
#  'look': True,
#  'little': True,
#  'odd': True,
#  '"': True,
#  'graphic': True,
#  'novel': True,
#  'if': True,
#  'you': True,
#  'will': True,
#  'over': True,
#  '500': True,
#  'pages': True,
#  'long': True,
#  'includes': True,
#  'nearly': True,
#  '30': True,
#  'more': True,
#  'that': True,
#  'consist': True,
#  'nothing': True,
#  'footnotes': True,
#  'other': True,
#  'words': True,
#  'don': True,
#  't': True,
#  'dismiss': True,
#  'this': True,
#  'film': True,
#  'because': True,
#  'its': True,
#  'source': True,
#  'can': True,
#  'get': True,
#  'past': True,
#  'thing': True,
#  'might': True,
#  'find': True,
#  'another': True,
#  'stumbling': True,
#  'block': True,
#  'directors': True,
#  'albert': True,
#  'allen': True,
#  'hughes': True,
#  'getting': True,
#  'brothers': True,
#  'direct': True,
#  'seems': True,
#  'almost': True,
#  'as': True,
#  'ludicrous': True,
#  'casting': True,
#  'carrot': True,
#  'top': True,
#  'well': True,
#  'anything': True,
#  'riddle': True,
#  'me': True,
#  ':': True,
#  'better': True,
#  'set': True,
#  'ghetto': True,
#  'features': True,
#  'violent': True,
#  'street': True,
#  'crime': True,
#  'than': True,
#  'mad': True,
#  'geniuses': True,
#  'behind': True,
#  'menace': True,
#  'ii': True,
#  'society': True,
#  '?': True,
#  'question': True,
#  'course': True,
#  'whitechapel': True,
#  '1888': True,
#  'london': True,
#  'east': True,
#  'end': True,
#  'filthy': True,
#  'sooty': True,
#  'place': True,
#  'where': True,
#  'whores': True,
#  'unfortunates': True,
#  'are': True,
#  'nervous': True,
#  'mysterious': True,
#  'psychopath': True,
#  'has': True,
#  'carving': True,
#  'through': True,
#  'their': True,
#  'profession': True,
#  'surgical': True,
#  'precision': True,
#  'when': True,
#  'first': True,
#  'stiff': True,
#  'turns': True,
#  'up': True,
#  'copper': True,
#  'peter': True,
#  'godley': True,
#  'robbie': True,
#  'coltrane': True,
#  'not': True,
#  'enough': True,
#  'calls': True,
#  'inspector': True,
#  'frederick': True,
#  'abberline': True,
#  'johnny': True,
#  'depp': True,
#  'blow': True,
#  'crack': True,
#  'case': True,
#  'widower': True,
#  'prophetic': True,
#  'dreams': True,
#  'he': True,
#  'unsuccessfully': True,
#  'tries': True,
#  'quell': True,
#  'copious': True,
#  'amounts': True,
#  'absinthe': True,
#  'opium': True,
#  'upon': True,
#  'arriving': True,
#  'befriends': True,
#  'an': True,
#  'unfortunate': True,
#  'named': True,
#  'mary': True,
#  'kelly': True,
#  'heather': True,
#  'graham': True,
#  'isn': True,
#  'so': True,
#  'proceeds': True,
#  'investigate': True,
#  'horribly': True,
#  'gruesome': True,
#  'crimes': True,
#  'even': True,
#  'police': True,
#  'surgeon': True,
#  'stomach': True,
#  'i': True,
#  'think': True,
#  'anyone': True,
#  'needs': True,
#  'briefed': True,
#  'on': True,
#  'won': True,
#  'go': True,
#  'into': True,
#  'particulars': True,
#  'here': True,
#  'unique': True,
#  'interesting': True,
#  'theory': True,
#  'both': True,
#  'identity': True,
#  'killer': True,
#  'reasons': True,
#  'chooses': True,
#  'slay': True,
#  'bother': True,
#  'cloaking': True,
#  'screenwriters': True,
#  'terry': True,
#  'hayes': True,
#  'vertical': True,
#  'limit': True,
#  'rafael': True,
#  'yglesias': True,
#  'les': True,
#  'mis': True,
#  'rables': True,
#  'do': True,
#  'good': True,
#  'job': True,
#  'keeping': True,
#  'him': True,
#  'hidden': True,
#  'viewers': True,
#  'until': True,
#  'very': True,
#  'funny': True,
#  'watch': True,
#  'locals': True,
#  'blindly': True,
#  'point': True,
#  'finger': True,
#  'blame': True,
#  'at': True,
#  'jews': True,
#  'indians': True,
#  'after': True,
#  'all': True,
#  'englishman': True,
#  'could': True,
#  'capable': True,
#  'committing': True,
#  'such': True,
#  'ghastly': True,
#  'acts': True,
#  'ending': True,
#  'whistling': True,
#  'stonecutters': True,
#  'song': True,
#  'simpsons': True,
#  'days': True,
#  'holds': True,
#  'back': True,
#  'electric': True,
#  'car': True,
#  '/': True,
#  'made': True,
#  'steve': True,
#  'guttenberg': True,
#  'star': True,
#  'worry': True,
#  'll': True,
#  'make': True,
#  'sense': True,
#  'see': True,
#  'now': True,
#  'onto': True,
#  'appearance': True,
#  'certainly': True,
#  'dark': True,
#  'bleak': True,
#  'surprising': True,
#  'how': True,
#  'much': True,
#  'looks': True,
#  'tim': True,
#  'burton': True,
#  'planet': True,
#  'apes': True,
#  'did': True,
#  'times': True,
#  'sleepy': True,
#  'hollow': True,
#  '2': True,
#  'print': True,
#  'saw': True,
#  'wasn': True,
#  'completely': True,
#  'finished': True,
#  'color': True,
#  'music': True,
#  'finalized': True,
#  'no': True,
#  'comments': True,
#  'marilyn': True,
#  'manson': True,
#  'cinematographer': True,
#  'deming': True,
#  'word': True,
#  'ably': True,
#  'captures': True,
#  'dreariness': True,
#  'victorian': True,
#  'era': True,
#  'helped': True,
#  'flashy': True,
#  'killing': True,
#  'scenes': True,
#  'remind': True,
#  'crazy': True,
#  'flashbacks': True,
#  'twin': True,
#  'peaks': True,
#  'though': True,
#  'violence': True,
#  'pales': True,
#  'comparison': True,
#  'black': True,
#  'white': True,
#  'oscar': True,
#  'winner': True,
#  'martin': True,
#  'childs': True,
#  'shakespeare': True,
#  'love': True,
#  'production': True,
#  'design': True,
#  'original': True,
#  'prague': True,
#  'surroundings': True,
#  'one': True,
#  'creepy': True,
#  'acting': True,
#  'solid': True,
#  'dreamy': True,
#  'turning': True,
#  'typically': True,
#  'strong': True,
#  'performance': True,
#  'deftly': True,
#  'handling': True,
#  'british': True,
#  'accent': True,
#  'ians': True,
#  'holm': True,
#  'joe': True,
#  'gould': True,
#  'secret': True,
#  'richardson': True,
#  '102': True,
#  'dalmatians': True,
#  'log': True,
#  'great': True,
#  'supporting': True,
#  'roles': True,
#  'big': True,
#  'surprise': True,
#  'cringed': True,
#  'time': True,
#  'she': True,
#  'opened': True,
#  'her': True,
#  'mouth': True,
#  'imagining': True,
#  'attempt': True,
#  'irish': True,
#  'actually': True,
#  'half': True,
#  'bad': True,
#  'however': True,
#  '00': True,
#  'r': True,
#  'gore': True,
#  'sexuality': True,
#  'language': True,
#  'drug': True,
#  'content': True}

# %%
training_feature_vector = [(extract_unigram_feature(words), label) for (words, label) in training_data]
print(training_feature_vector[:1])
# Out:
# [({'films': True, 'adapted': True, 'from': True, 'comic': True, 'books': True, 'have': True, 'had': True, 'plenty': True, 'of': True, 'success': True, ',': True, 'whether': True, 'they': True, "'": True, 're': True, 'about': True, 'superheroes': True, '(': True, 'batman': True, 'superman': True, 'spawn': True, ')': True, 'or': True, 'geared': True, 'toward': True, 'kids': True, 'casper': True, 'the': True, 'arthouse': True, 'crowd': True, 'ghost': True, 'world': True, 'but': True, 'there': True, 's': True, 'never': True, 'really': True, 'been': True, 'a': True, 'book': True, 'like': True, 'hell': True, 'before': True, '.': True, 'for': True, 'starters': True, 'it': True, 'was': True, 'created': True, 'by': True, 'alan': True, 'moore': True, 'and': True, 'eddie': True, 'campbell': True, 'who': True, 'brought': True, 'medium': True, 'to': True, 'whole': True, 'new': True, 'level': True, 'in': True, 'mid': True, '80s': True, 'with': True, '12': True, '-': True, 'part': True, 'series': True, 'called': True, 'watchmen': True, 'say': True, 'thoroughly': True, 'researched': True, 'subject': True, 'jack': True, 'ripper': True, 'would': True, 'be': True, 'saying': True, 'michael': True, 'jackson': True, 'is': True, 'starting': True, 'look': True, 'little': True, 'odd': True, '"': True, 'graphic': True, 'novel': True, 'if': True, 'you': True, 'will': True, 'over': True, '500': True, 'pages': True, 'long': True, 'includes': True, 'nearly': True, '30': True, 'more': True, 'that': True, 'consist': True, 'nothing': True, 'footnotes': True, 'other': True, 'words': True, 'don': True, 't': True, 'dismiss': True, 'this': True, 'film': True, 'because': True, 'its': True, 'source': True, 'can': True, 'get': True, 'past': True, 'thing': True, 'might': True, 'find': True, 'another': True, 'stumbling': True, 'block': True, 'directors': True, 'albert': True, 'allen': True, 'hughes': True, 'getting': True, 'brothers': True, 'direct': True, 'seems': True, 'almost': True, 'as': True, 'ludicrous': True, 'casting': True, 'carrot': True, 'top': True, 'well': True, 'anything': True, 'riddle': True, 'me': True, ':': True, 'better': True, 'set': True, 'ghetto': True, 'features': True, 'violent': True, 'street': True, 'crime': True, 'than': True, 'mad': True, 'geniuses': True, 'behind': True, 'menace': True, 'ii': True, 'society': True, '?': True, 'question': True, 'course': True, 'whitechapel': True, '1888': True, 'london': True, 'east': True, 'end': True, 'filthy': True, 'sooty': True, 'place': True, 'where': True, 'whores': True, 'unfortunates': True, 'are': True, 'nervous': True, 'mysterious': True, 'psychopath': True, 'has': True, 'carving': True, 'through': True, 'their': True, 'profession': True, 'surgical': True, 'precision': True, 'when': True, 'first': True, 'stiff': True, 'turns': True, 'up': True, 'copper': True, 'peter': True, 'godley': True, 'robbie': True, 'coltrane': True, 'not': True, 'enough': True, 'calls': True, 'inspector': True, 'frederick': True, 'abberline': True, 'johnny': True, 'depp': True, 'blow': True, 'crack': True, 'case': True, 'widower': True, 'prophetic': True, 'dreams': True, 'he': True, 'unsuccessfully': True, 'tries': True, 'quell': True, 'copious': True, 'amounts': True, 'absinthe': True, 'opium': True, 'upon': True, 'arriving': True, 'befriends': True, 'an': True, 'unfortunate': True, 'named': True, 'mary': True, 'kelly': True, 'heather': True, 'graham': True, 'isn': True, 'so': True, 'proceeds': True, 'investigate': True, 'horribly': True, 'gruesome': True, 'crimes': True, 'even': True, 'police': True, 'surgeon': True, 'stomach': True, 'i': True, 'think': True, 'anyone': True, 'needs': True, 'briefed': True, 'on': True, 'won': True, 'go': True, 'into': True, 'particulars': True, 'here': True, 'unique': True, 'interesting': True, 'theory': True, 'both': True, 'identity': True, 'killer': True, 'reasons': True, 'chooses': True, 'slay': True, 'bother': True, 'cloaking': True, 'screenwriters': True, 'terry': True, 'hayes': Tr ...

# %%
testing_feature_vector = [(extract_unigram_feature(words), label) for (words, label) in testing_data]
print(testing_feature_vector[:1])
# Out:
# [({'in': True, '1912': True, ',': True, 'a': True, 'ship': True, 'set': True, 'sail': True, 'on': True, 'her': True, 'maiden': True, 'voyage': True, 'across': True, 'the': True, 'atlantic': True, 'for': True, 'america': True, '.': True, 'this': True, 'was': True, 'built': True, 'to': True, 'be': True, 'largest': True, 'world': True, 'and': True, 'she': True, 'also': True, 'build': True, 'one': True, 'of': True, 'most': True, 'luxurious': True, 'that': True, 'finally': True, 'unsinkable': True, 'unfortunately': True, 'not': True, 'get': True, 'ticket': True, 'you': True, 'either': True, ':': True, 'spent': True, 'life': True, "'": True, 's': True, 'savings': True, 'start': True, 'anew': True, 'were': True, 'part': True, 'upper': True, 'class': True, 'had': True, 'money': True, 'spare': True, 'or': True, 'lucky': True, 'enough': True, 'have': True, 'full': True, 'house': True, 'poker': True, 'match': True, 'by': True, 'docks': True, 'like': True, 'jack': True, 'dawson': True, 'makes': True, 'trip': True, 'happens': True, 'at': True, 'right': True, 'place': True, 'time': True, 'rose': True, 'dewitt': True, 'bukater': True, 'first': True, 'passenger': True, 'climbs': True, 'railings': True, 'aft': True, 'with': True, 'thoughts': True, 'jumping': True, 'thus': True, 'is': True, 'started': True, 'tale': True, 'romance': True, 'intrigue': True, 'death': True, 'tragedy': True, 'movie': True, 'about': True, 'tragic': True, 'event': True, 'took': True, 'great': True, 'many': True, 'years': True, 'ago': True, 'an': True, 'even': True, 'should': True, 'taken': True, 'lightly': True, 'as': True, 'any': True, 'other': True, 'bit': True, 'historical': True, 'trivia': True, 'titanic': True, 'shows': True, 'what': True, 'happened': True, 'maybe': True, '100': True, '%': True, 'degree': True, 'accuracy': True, 'but': True, 'it': True, 'still': True, 'very': True, 'realisticaly': True, 'now': True, 'both': True, 'story': True, 'its': True, 'own': True, 'backdrop': True, 'serves': True, 'admirably': True, 'brining': True, 'forth': True, 'interesting': True, 'although': True, 'simple': True, 'premise': True, 'captivating': True, 'emotional': True, 'simply': True, 'because': True, 'alone': True, 'brought': True, 'out': True, 'certain': True, 'style': True, 'so': True, 'much': True, 'more': True, 'effective': True, 'movies': True, 'such': True, 'will': True, 'forgotten': True, 'all': True, 'too': True, 'quickly': True, 'then': True, 'are': True, 'something': True, 'produced': True, 'hollywood': True, 'frequency': True, 'attention': True, 'detail': True, 'paid': True, 'remarkable': True, 'whole': True, 'telling': True, 'showing': True, 'brand': True, 'new': True, 'footage': True, 'from': True, 'wreck': True, 'adding': True, 'flavor': True, 'already': True, 'good': True, 'magical': True, 'chemistry': True, 'behind': True, 'acting': True, 'extremely': True, 'cast': True, 'performances': True, 'put': True, 'main': True, 'stars': True, 'admired': True, 'characters': True, 'played': True, 'memorably': True, 'leonardo': True, 'dicaprip': True, 'kate': True, 'winslet': True, 'receive': True, 'least': True, 'nominations': True, 'their': True, 'roles': True, 'looking': True, 'done': True, 'seems': True, 'if': True, 'they': True, 'aren': True, 't': True, 'actually': True, 'casting': True, 'could': True, 'really': True, 'been': True, 'better': True, 'my': True, 'humble': True, 'opinion': True, 'character': True, 'likely': True, 'mentioned': True, 'review': True, 'commentary': True, 'film': True, 'itself': True, 'yes': True, 'read': True, 'correctly': True, 'how': True, '?': True, 'ask': True, 'well': True, 'sailors': True, 'boats': True, 'men': True, 'tell': True, 'everything': True, 'specifications': True, 'luxuries': True, 'no': True, 'stranger': True, 'mr': True, 'cameron': True, 'brings': True, 'almost': True, 'literal': True, 'sense': True, 'adds': True, 'way': True, 'productions': True, 'cant': True, 'seem': True, 'grasp': True, 'produce': True, 'effect': ...

# %% [markdown]
# ## Train The Naive Bayes Classifier

# %%
training_feature_vector[:1]
# Out:
# [({'films': True,
#    'adapted': True,
#    'from': True,
#    'comic': True,
#    'books': True,
#    'have': True,
#    'had': True,
#    'plenty': True,
#    'of': True,
#    'success': True,
#    ',': True,
#    'whether': True,
#    'they': True,
#    "'": True,
#    're': True,
#    'about': True,
#    'superheroes': True,
#    '(': True,
#    'batman': True,
#    'superman': True,
#    'spawn': True,
#    ')': True,
#    'or': True,
#    'geared': True,
#    'toward': True,
#    'kids': True,
#    'casper': True,
#    'the': True,
#    'arthouse': True,
#    'crowd': True,
#    'ghost': True,
#    'world': True,
#    'but': True,
#    'there': True,
#    's': True,
#    'never': True,
#    'really': True,
#    'been': True,
#    'a': True,
#    'book': True,
#    'like': True,
#    'hell': True,
#    'before': True,
#    '.': True,
#    'for': True,
#    'starters': True,
#    'it': True,
#    'was': True,
#    'created': True,
#    'by': True,
#    'alan': True,
#    'moore': True,
#    'and': True,
#    'eddie': True,
#    'campbell': True,
#    'who': True,
#    'brought': True,
#    'medium': True,
#    'to': True,
#    'whole': True,
#    'new': True,
#    'level': True,
#    'in': True,
#    'mid': True,
#    '80s': True,
#    'with': True,
#    '12': True,
#    '-': True,
#    'part': True,
#    'series': True,
#    'called': True,
#    'watchmen': True,
#    'say': True,
#    'thoroughly': True,
#    'researched': True,
#    'subject': True,
#    'jack': True,
#    'ripper': True,
#    'would': True,
#    'be': True,
#    'saying': True,
#    'michael': True,
#    'jackson': True,
#    'is': True,
#    'starting': True,
#    'look': True,
#    'little': True,
#    'odd': True,
#    '"': True,
#    'graphic': True,
#    'novel': True,
#    'if': True,
#    'you': True,
#    'will': True,
#    'over': True,
#    '500': True,
#    'pages': True,
#    'long': True,
#    'includes': True,
#    'nearly': True,
#    '30': True,
#    'more': True,
#    'that': True,
#    'consist': True,
#    'nothing': True,
#    'footnotes': True,
#    'other': True,
#    'words': True,
#    'don': True,
#    't': True,
#    'dismiss': True,
#    'this': True,
#    'film': True,
#    'because': True,
#    'its': True,
#    'source': True,
#    'can': True,
#    'get': True,
#    'past': True,
#    'thing': True,
#    'might': True,
#    'find': True,
#    'another': True,
#    'stumbling': True,
#    'block': True,
#    'directors': True,
#    'albert': True,
#    'allen': True,
#    'hughes': True,
#    'getting': True,
#    'brothers': True,
#    'direct': True,
#    'seems': True,
#    'almost': True,
#    'as': True,
#    'ludicrous': True,
#    'casting': True,
#    'carrot': True,
#    'top': True,
#    'well': True,
#    'anything': True,
#    'riddle': True,
#    'me': True,
#    ':': True,
#    'better': True,
#    'set': True,
#    'ghetto': True,
#    'features': True,
#    'violent': True,
#    'street': True,
#    'crime': True,
#    'than': True,
#    'mad': True,
#    'geniuses': True,
#    'behind': True,
#    'menace': True,
#    'ii': True,
#    'society': True,
#    '?': True,
#    'question': True,
#    'course': True,
#    'whitechapel': True,
#    '1888': True,
#    'london': True,
#    'east': True,
#    'end': True,
#    'filthy': True,
#    'sooty': True,
#    'place': True,
#    'where': True,
#    'whores': True,
#    'unfortunates': True,
#    'are': True,
#    'nervous': True,
#    'mysterious': True,
#    'psychopath': True,
#    'has': True,
#    'carving': True,
#    'through': True,
#    'their': True,
#    'profession': True,
#    'surgical': True,
#    'precision': True,
#    'when': True,
#    'first': True,
#    'stiff': True,
#    'turns': True,
#    'up': True,
#    'copper': True,
#    'peter': True,
#    'godley': True,
#    'robbie': True,
#    'coltrane': True,
#    'not': True,
#    'enough': True,
#    'calls': True,
#    'inspector': True,
#    'frederick': True,
#    'abberline': True,
#    'johnny': True,
#    'depp': True,
#    'blow': True,
#    'crack': True,
#    'case': True,
#    'widower': True,
#    'prophetic': True,
#    'dreams': True,
#    'he': True,
#    'unsuccessfully': True,
#    'tries': True,
#    'quell': True,
#    'copious': True,
#    'amounts': True,
#    'absinthe': True,
#    'opium': True,
#    'upon': True,
#    'arriving': True,
#    'befriends': True,
#    'an': True,
#    'unfortunate': True,
#    'named': True,
#    'mary': True,
#    'kelly': True,
#    'heather': True,
#    'graham': True,
#    'isn': True,
#    'so': True,
#    'proceeds': True,
#    'investigate': True,
#    'horribly': True,
#    'gruesome': True,
#    'crimes': True,
#    'even': True,
#    'police': True,
#    'surgeon': True,
#    'stomach': True,
#    'i': True,
#    'think': True,
#    'anyone': True,
#    'needs': True,
#    'briefed': True,
#    'on': True,
#    'won': True,
#    'go': True,
#    'into': True,
#    'particulars': True,
#    'here': True,
#    'unique': True,
#    'interesting': True,
#    'theory': True,
#    'both': True,
#    'identity': True,
#    'killer': True,
#    'reasons': True,
#    'chooses': True,
#    'slay': True,
#    'bother': True,
#    'cloaking': True,
#    'screenwriters': True,
#    'terry': True,
#    'hayes': True,
#    'vertical': True,
#    'limit': True,
#    'rafael': True,
#    'yglesias': True,
#    'les': True,
#    'mis': True,
#    'rables': True,
#    'do': True,
#    'good': True,
#    'job': True,
#    'keeping': True,
#    'him': True,
#    'hidden': True,
#    'viewers': True,
#    'until': True,
#    'very': True,
#    'funny': True,
#    'watch': True,
#    'locals': True,
#    'blindly': True,
#    'point': True,
#    'finger': True,
#    'blame': True,
#    'at': True,
#    'jews': True,
#    'indians': True,
#    'after': True,
#    'all': True,
#    'englishman': True,
#    'could': True,
#    'capable': True,
#    'committing': True,
#    'such': True,
#    'ghastly': True,
#    'acts': True,
#    'ending': True,
#    'whistling': True,
#    'stonecutters': True,
#    'song': True,
#    'simpsons': True,
#    'days': True,
#    'holds': True,
#    'back': True,
#    'electric': True,
#    'car': True,
#    '/': True,
#    'made': True,
#    'steve': True,
#    'guttenberg': True,
#    'star': True,
#    'worry': True,
#    'll': True,
#    'make': True,
#    'sense': True,
#    'see': True,
#    'now': True,
#    'onto': True,
#    'appearance': True,
#    'certainly': True,
#    'dark': True,
#    'bleak': True,
#    'surprising': True,
#    'how': True,
#    'much': True,
#    'looks': True,
#    'tim': True,
#    'burton': True,
#    'planet': True,
#    'apes': True,
#    'did': True,
#    'times': True,
#    'sleepy': True,
#    'hollow': True,
#    '2': True,
#    'print': True,
#    'saw': True,
#    'wasn': True,
#    'completely': True,
#    'finished': True,
#    'color': True,
#    'music': True,
#    'finalized': True,
#    'no': True,
#    'comments': True,
#    'marilyn': True,
#    'manson': True,
#    'cinematographer': True,
#    'deming': True,
#    'word': True,
#    'ably': True,
#    'captures': True,
#    'dreariness': True,
#    'victorian': True,
#    'era': True,
#    'helped': True,
#    'flashy': True,
#    'killing': True,
#    'scenes': True,
#    'remind': True,
#    'crazy': True,
#    'flashbacks': True,
#    'twin': True,
#    'peaks': True,
#    'though': True,
#    'violence': True,
#    'pales': True,
#    'comparison': True,
#    'black': True,
#    'white': True,
#    'oscar': True,
#    'winner': True,
#    'martin': True,
#    'childs': True,
#    'shakespeare': True,
#    'love': True,
#    'production': True,
#    'design': True,
#    'original': True,
#    'prague': True,
#    'surroundings': True,
#    'one': True,
#    'creepy': True,
#    'acting': True,
#    'solid': True,
#    'dreamy': True,
#    'turning': True,
#    'typically': True,
#    'strong': True,
#    'performance': True,
#    'deftly': True,
#    'handling': True,
#    'british': True,
#    'accent': True,
#    'ians': True,
#    'holm': True,
#    'joe': True,
#    'gould': True,
#    'secret': True,
#    'richardson': True,
#    '102': True,
#    'dalmatians': True,
#    'log': True,
#    'great': True,
#    'supporting': True,
#    'roles': True,
#    'big': True,
#    'surprise': True,
#    'cringed': True,
#    'time': True,
#    'she': True,
#    'opened': True,
#    'her': True,
#    'mouth': True,
#    'imagining': True,
#    'attempt': True,
#    'irish': True,
#    'actually': True,
#    'half': True,
#    'bad': True,
#    'however': True,
#    '00': True,
#    'r': True,
#    'gore': True,
#    'sexuality': True,
#    'language': True,
#    'drug': True,
#    'content': True},
#   'pos')]

# %% [markdown]
# #### ❓Exercise 3. Create the Naive Bayes classifier using the training data

# %% [markdown]
# Take note that the training process might take a while.

# %%
#
nb_classifier = nltk.NaiveBayesClassifier.train(training_feature_vector)

# %% [markdown]
# ## Evaluation

# %%
#predict the testing data
prediction = nb_classifier.classify(testing_feature_vector[0][0])
actual_class = testing_feature_vector[0][1]
print("Prediction:", prediction, " Actual class:", actual_class)
# Out:
# Prediction: pos  Actual class: pos

# %% [markdown]
# #### ❓Exercise 4. Determine the accuracy of the `nb_classifier`

# %%
# this is the basic train of processes for sentiment analysis
tokens = nltk.word_tokenize("i am not sad")
features = extract_unigram_feature(tokens)
nb_classifier.classify(features)
# notice that this model is not able to detect the negation 'not'
# Out:
# 'neg'

# %%
nltk.classify.accuracy(nb_classifier, testing_feature_vector)
# Out:
# 0.73

# %% [markdown]
# #### ❓Exercise 5. Investigate to see whether there is any changes to the accuracy if you have a different train/test split %

# %% [markdown]
# ===

# %% [markdown]
# ## Confusion Matrix

# %% [markdown]
# To properly evaluate the performance of a classifier, it is a good idea to generate the confusion matrix so that we can better assess how good/bad the classification results are. In this case, we want the classifier to predict `pos` as `pos` and `neg` as `neg`

# %%
predictions = [nb_classifier.classify(feature_vect[0]) for feature_vect in testing_feature_vector]
actual = [feature_vect[1] for feature_vect in testing_feature_vector]

# %%
labels = ["pos","neg"]

# %%
cm = confusion_matrix(actual, predictions, labels=labels)
cm
# Out:
# array([[97,  3],
#        [51, 49]], dtype=int64)

# %%
#predicted value is the row
#actual value is the column
#the accuracy = (sum of the diagram) / (total number of testing data)
pd.DataFrame(cm,
             index = labels, 
             columns = labels)
# Out:
#      pos  neg
# pos   97    3
# neg   51   49
